# %% [markdown]
# # Testing Asian Option

# %%
import matplotlib.pyplot as plt
import numpy as np
import qmcpy as qp
import time  #timing routines
import warnings  #to suppress warnings when needed

# %%
ac = qp.AsianOption(qp.DigitalNetB2(4,seed=7))
ac
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/qmcpy/lib/python3.9/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/miniconda3/envs/qmcpy/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/miniconda3/envs/qmcpy/lib/python3.9/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/SoftwareRepositories/QMCSoftware/qmcpy/integrand/_integrand.py:257, in Integrand.__repr__(self)
#     256 def __repr__(self):
# --> 257     return _univ_repr(self, "Integrand", self.parameters)
#
# File ~/SoftwareRepositories/QMCSoftware/qmcpy/util/abstraction_functions.py:31, in _univ_repr(qmc_object, abc_class_name, attributes)
#      29 string = "%s (%s Object)" % (type(qmc_object).__name__, abc_class_name)
#      30 for key in unique_attributes:
# ---> 31     val = getattr(qmc_object, key)
#      32     # list of one value becomes just that value
#      33     if isinstance(val, list) and len(val) == 1:
#
# AttributeError: 'AsianOption' object has no attribute 'dim_frac'

# %%
! pip list
# Out:
# Package                       Version        Editable project location
# ----------------------------- -------------- ------------------------------------------------------
# aiohttp                       3.9.5
# aiosignal                     1.3.1
# alabaster                     0.7.16
# anyio                         4.4.0
# appnope                       0.1.4
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# astroid                       2.11.7
# asttokens                     2.4.1
# async-lru                     2.0.4
# async-timeout                 4.0.3
# asyncio                       3.4.3
# attrs                         23.2.0
# Babel                         2.14.0
# beautifulsoup4                4.12.3
# bleach                        6.1.0
# botorch                       0.8.5
# Brotli                        1.1.0
# certifi                       2024.7.4
# cffi                          1.16.0
# charset-normalizer            3.3.2
# colorama                      0.4.6
# comm                          0.2.2
# commonmark                    0.9.1
# coverage                      6.4.1
# cycler                        0.12.1
# debugpy                       1.8.2
# decorator                     5.1.1
# defusedxml                    0.7.1
# dill                          0.3.8
# docutils                      0.17.1
# exceptiongroup                1.2.2
# executing                     2.0.1
# fastjsonschema                2.20.0
# filelock                      3.15.4
# fonttools                     4.53.1
# fqdn                          1.5.1
# frozenlist                    1.4.1
# fsspec                        2024.6.1
# gpytorch                      1.10
# h11                           0.14.0
# h2                            4.1.0
# hpack                         4.0.0
# httpcore                      1.0.5
# httpx                         0.27.0
# hyperframe                    6.0.1
# idna                          3.7
# imagesize                     1.4.1
# importlib_metadata            8.0.0
# iniconfig                     2.0.0
# ipykernel                     6.29.5
# ipython                       8.18.1
# ipywidgets                    8.1.3
# isoduration                   20.11.0
# isort                         5.13.2
# jedi                          0.19.1
# Jinja2                        3.1.4
# joblib                        1.4.2
# json5                         0.9.25
# jsonpointer                   3.0.0
# jsonschema                    4.23.0
# jsonschema-specifications     2023.12.1
# jupyter                       1.0.0
# jupyter_client                8.6.2
# jupyter-console               6.6.3
# jupyter_core                  5.7.2
# jupyter-events                0.10.0
# jupyter-lsp                   2.2.5
# jupyter_server                2.14.2
# jupyter_server_terminals      0.5.3
# jupyterlab                    4.2.3
# jupyterlab-execute-time       3.1.2
# jupyterlab_pygments           0.3.0
# jupyterlab_server             2.27.2
# jupyterlab_widgets            3.0.11
# kiwisolver                    1.4.5
# lazy-object-proxy             1.10.0
# linear-operator               0.4.0
# Markdown                      3.6
# MarkupSafe                    2.1.5
# matplotlib                    3.5.2
# matplotlib-inline             0.1.7
# mccabe                        0.7.0
# mistune                       3.0.2
# mpmath                        1.3.0
# multidict                     6.0.5
# multipledispatch              1.0.0
# nbclient                      0.10.0
# nbconvert                     7.16.4
# nbformat                      5.10.4
# nest-asyncio                  1.6.0
# networkx                      3.2.1
# notebook                      7.2.1
# notebook_shim                 0.2.4
# numpy                         1.23.4
# opt-einsum                    3.3.0
# overrides                     7.7.0
# packaging                     24.1
# pandas                        1.4.3
# pandocfilters                 1.5.1
# parso                         0.8.4
# pexpect                       4.9.0
# pillow                        10.4.0
# pip                           24.1.2
# platformdirs                  4.2.2
# pluggy                        1.5.0
# prometheus_client             0.20.0
# prompt_toolkit                3.0.47
# psutil                        6.0.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pycparser                     2.22
# Pygments                      2.18.0
# pylint                        2.14.4
# pyparsing                     3.1.2
# pyro-api                      0.1.2
# pyro-ppl                      1.9.1
# PySocks                       1.7.1
# pytest                        7.1.2
# python-dateutil               2.9.0.post0
# python-json-logger            2.0.7
# pytz                          2024.1
# PyYAML                        6.0.1
# pyzmq                         26.0.3
# qmcpy                         1.5            /Users/fredhickernell/SoftwareRepositories/QMCSoftware
# qtconsole                     5.5.2
# QtPy                          2.4.1
# recommonmark                  0.7.1
# referencing                   0.35.1
# requests                      2.32.3
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rpds-py                       0.19.0
# scikit-learn                  1.5.1
# scipy                         1.9.3
# Send2Trash                    1.8.3
# setuptools                    70.3.0
# simple-colors                 0.1.5
# six                           1.16.0
# sniffio                       1.3.1
# snowballstemmer               2.2.0
# soupsieve                     2.5
# Sphinx                        5.0.2
# sphinx-markdown-tables        0.0.17
# sphinx-math-dollar            1.2.1
# sphinx-rtd-theme              1.0.0
# sphinxcontrib-applehelp       1.0.8
# sphinxcontrib-devhelp         1.0.6
# sphinxcontrib-htmlhelp        2.0.5
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.7
# sphinxcontrib-serializinghtml 1.1.10
# stack-data                    0.6.3
# sympy                         1.13.0
# tabulate                      0.9.0
# terminado                     0.18.1
# threadpoolctl                 3.5.0
# tinycss2                      1.3.0
# tomli                         2.0.1
# tomlkit                       0.13.0
# torch                         2.3.1
# tornado                       6.4.1
# tqdm                          4.66.4
# traitlets                     5.14.3
# types-python-dateutil         2.9.0.20240316
# typing_extensions             4.12.2
# umbridge                      1.2.1
# UniformSumDistribution        1.0.3
# uri-template                  1.3.0
# urllib3                       2.2.2
# wcwidth                       0.2.13
# webcolors                     24.6.0
# webencodings                  0.5.1
# websocket-client              1.8.0
# wheel                         0.43.0
# widgetsnbextension            4.0.11
# wrapt                         1.16.0
# yarl                          1.9.4
# zipp                          3.19.2
# zstandard                     0.22.0
