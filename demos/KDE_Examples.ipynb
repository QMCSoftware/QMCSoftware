# %% [markdown]
# # Kernel Density Estimation Examples for Various Cases

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import scipy as sp
import qmcpy as qp
import pandas as pd
from scipy import stats
from simple_colors import *
from copy import deepcopy
import sympy as sy
import sympy.stats
import pickle
#!pip install UniformSumDistribution
from UniformSumDistribution import UniformSumDistribution
figpath = 'KDE_Ex_Output/' #this path sends the figures to the directory that you want
fig_format = 'pdf'

# %% [markdown]
# ## What we still need to do
# * Plot error versus n
# * Plot h versus n
# * Correct for finite bounds on $Y$
# * Try kernels with higher accuracies
# * Include conditional Monte Carlo
# * Can we do a kde without for loops (done)
# * Compute times
# * fix git

# %% [markdown]
# ### Some LaTeX macros (hidden in math mode)
# $
# \newcommand{\vt}{\boldsymbol{t}}
# \newcommand{\vx}{\boldsymbol{x}}
# \newcommand{\vX}{\boldsymbol{X}}
# \newcommand{\cf}{\mathcal{F}}
# \newcommand{\cu}{\mathcal{U}}
# \newcommand{\dif}{\mathrm{d}}
# \newcommand{\Ex}{\mathbb{E}}
# \DeclareMathOperator{\disc}{disc}
# \newcommand{\norm}[2][{}]{{\left \lVert #2 \right \rVert}_{#1}}
# $

# %% [markdown]
# ## Set Up Functions of Uniform Random Variables and Their Densities

# %% [markdown]
# ### A dictionary for each $f$

# %% [markdown]
# #### Weighted sum of Gaussians is a Gaussian

# %%
def sum_d_Gauss_case(): #Sum of Gaussian random variables
    def fullwts(d = 1,coord_wts = 1):
        fw = coord_wts[:np.min([d,coord_wts.shape[0]])] * np.ones(d) #expand the weights to fit the dimension
        stdev = np.sqrt(np.sum(fw**2))  #square root of sum of squares of weights
        return fw, stdev
    def f(x,d = 1,coord_wts = 1):   #is there a way to avoid having to use squeeze
        if d == 1:
            return np.squeeze(sp.stats.norm.ppf(x) * fullwts(d,coord_wts)[0])
        else:
            return np.squeeze(np.sum(sp.stats.norm.ppf(x) * fullwts(d,coord_wts)[0], axis = -1))
    def density(y,d = 1,coord_wts = 1):
        return sp.stats.norm.pdf(y, scale = fullwts(d,coord_wts)[1])
    return {"f" : f,       #return a dictionary
            "density" : density,  #probability density of f(X) where X is IID U([0,1]^d)
            "y_plt_domain" : lambda d,coord_wts : np.array([-3.,3.])*fullwts(d,coord_wts)[1],  #domain for plotting the density
            "y_domain" : lambda d, coord_wts : np.array([float("-inf"),float("inf")]),  #sample space of Y = f(X)
            "name" : lambda d,coord_wts : f"Weighted Sum of {d:.0f} Gaussians",  #Plot label for density
            "d_allowed" : [float('inf')]
    }
sum_d_Gauss_case()["y_plt_domain"](1,np.array([1,1]))
# Out:
# array([-3.,  3.])

# %% [markdown]
# #### Weighted sum of uniforms is an [Irwin-Hall distribution](https://en.wikipedia.org/wiki/Irwin–Hall_distribution)

# %%
def sum_d_unif_case(): #Sum of uniform random variables
    def f(x,d = 1,coord_wts = 1):
        assert x.ndim > 1
        return x.sum(axis = -1)
    def density(y,d = 1,coord_wts = 1):
        return UniformSumDistribution(d).pdf(y)
    return {"f" : f,       #return a dictionary
            "density" : density,  #probability density of f(X) where X is IID U([0,1]^d)
            "y_plt_domain" : lambda d,coord_wts : np.array([-0.1,d+0.1]),  #domain for plotting the density
            "y_domain" : lambda d, coord_wts : np.array([0,d]),  #sample space of Y = f(X)
            "name" : lambda d,coord_wts : f"Weighted Sum of {d:.0f} uniforms",  #Plot label for density
            "d_allowed" : [float('inf')]
    }

d = 1
x = np.random.rand(8,d)
print("x =",x)
y = sum_d_unif_case()["f"](x,d)
print("y has shape",y.shape,"and values ",y)
sum_d_unif_case()["y_plt_domain"](1,np.array([1,1]))
# Out:
# x = [[0.59669874]
#  [0.29887619]
#  [0.9099877 ]
#  [0.60082861]
#  [0.24950243]
#  [0.0545541 ]
#  [0.72201455]
#  [0.32035127]]
# y has shape (8,) and values  [0.59669874 0.29887619 0.9099877  0.60082861 0.24950243 0.0545541
#  0.72201455 0.32035127]
# array([-0.1,  1.1])

# %% [markdown]
# #### Put the cases together

# %%
ex_densities = [sum_d_unif_case(),sum_d_Gauss_case()]
#ex_densities = [sum_d_unif_case()]
dens_kwargs = {"d" : 5, "coord_wts" : np.array(range(1,11))**-2.}
print(ex_densities[1]["y_plt_domain"](**dens_kwargs))
dens_kwargs = {"d" : 2, "coord_wts" : np.array(range(1,11))**-2.}
print(ex_densities[0]["f"](np.array([[0.5,0.4],]),**dens_kwargs))
print(ex_densities[0]["f"](np.array([[0.5,0.4],[0.2,0.3]]),**dens_kwargs))
print(ex_densities[1]["f"](np.array([[0.5,0.4],]),**dens_kwargs))
print(ex_densities[1]["f"](np.array([[0.5,0.4],[0.2,0.3]]),**dens_kwargs))
# Out:
# [-3.11819938  3.11819938]
# [0.9]
# [0.9 0.5]
# -0.06333677578394993
# [-0.06333678 -0.97272136]

# %% [markdown]
# ## Set up sampling schemes

# %%
samplers = [{"gen_sample" : lambda d, n : qp.IIDStdUniform(d).gen_samples(n),
            "sample_name" : "IID"},
           {"gen_sample" : lambda d, n : qp.Sobol(d).gen_samples(n),
            "sample_name" : "Sobol'"},
           {"gen_sample" : lambda d, n : qp.Lattice(d).gen_samples(n),
            "sample_name" : "lattice"},          
           {"gen_sample" : lambda d, n : qp.Halton(d).gen_samples(n),
            "sample_name" : "Halton"}]

# %% [markdown]
# ## Define a kernel density estimator

# %%
def kdeold(kernel, ydata, yeval = np.array([0]), bandwidth = 1):
    kernel_val = np.exp(-((ydata.reshape(len(ydata),1) - yeval.reshape(1,len(yeval)))/bandwidth)**2)/(bandwidth*np.sqrt(np.pi))
    return np.mean(kernel_val,axis = 0) 

def kde(ydata, yeval = np.array([0]), 
          kernel = {"name" : "Gauss", "bandwidth" : 1, "domain" : np.array([float('-inf'), float('inf')])}):  #a kernel for kernel density estimation(KDE)
    '''
        kernel = the choice of kernel
        ydata = the observations of Y used to construct the KDE
        yeval = the values of y where the density is to be approximated
        bandwidth = the bandwidth of the kernel
        domain = (a,b) = sample space of Y
    '''
    h = kernel["bandwidth"]
    a = kernel["domain"][0]
    b = kernel["domain"][1]
    n_data = len(ydata)
    n_eval = len(yeval)
    if kernel["name"] == "Gauss":
        kernel_val = np.exp(-((ydata.reshape(n_data,1) - yeval.reshape(1,n_eval))/h)**2)
        normal_fac_vals = (sp.special.erf((b-ydata)/h) - sp.special.erf((a-ydata)/h))/2
        kernel_val = kernel_val / normal_fac_vals.reshape(n_data,1)  #correction to the kernel for the restricted sample space
        domain_window = ((yeval >= a) & (yeval <= b))  #restricted sample space
        #print(domain_window)
    return np.mean(kernel_val,axis = 0)*domain_window/(h*np.sqrt(np.pi))

ndata = 1000
neval = 10
bandwidth = 0.1
kernel = {"name" : "Gauss", 
          "bandwidth" : 0.1, 
          "domain" : np.array([0,1])}
ydata = qp.IIDStdUniform(1).gen_samples(ndata)
yeval = np.linspace(-0.1,1.1,neval)
print("yeval = ",yeval)
#print(kernelbd(np.array([-1, 0, 1])))
#print(kernel(ydata,yeval,bandwidth))
#print(kde(ydata, yeval))
print(kdebd(ydata, yeval, kernel))

def error_rho(rhoexact,rhoapp,h_list,kind_of_err = ["rmse"]):  #Compute different error measures for the KDE
    err_out = dict.fromkeys(kind_of_err)
    ''' 
    In this dictionary output
                          key = kind of error measure
        0th entry in the list = where the best bandwidth occurs
        1st entry in the list = best bandwidth
        2nd entry in the list = best error
        rest of the entries   = errors of all bandwidths
    '''
    err_rho = rhoexact - rhoapp  #pointwise error
    if "rmse" in kind_of_err:  #root mean squared error                           
        rmse = np.sqrt((err_rho**2).mean(1))
        where_min = rmse.argmin()
        err_out["rmse"] = [where_min, h_list[where_min], rmse[where_min], *rmse]
    if "mae" in kind_of_err:  #mean absolute error
        mae = np.abs(err_rho).mean(1)
        where_min = mae.argmin()
        err_out["mae"] = [where_min, h_list[where_min], mae[where_min], *mae]
    if "sup" in kind_of_err:  #supremum or maximum of error
        sup = np.abs(err_rho).max(1)
        where_min = sup.argmin()
        err_out["sup"] = [where_min, h_list[where_min], maxe[where_min], *sup]    
    return err_out
# Out:
# yeval =  [-0.1         0.03333333  0.16666667  0.3         0.43333333  0.56666667
#   0.7         0.83333333  0.96666667  1.1       ]
# [False  True  True  True  True  True  True  True  True False]
# [0.         0.84339453 0.97715777 0.96048623 1.007509   1.08663349
#  1.11783214 1.02552203 0.83392045 0.        ]

# %% [markdown]
# ## Plot results of experiments

# %% [markdown]
# ### Remember to load the data to plot

# %%
wh_err = "mae"
n_rep = 15
n_max = 2**9
d_max = 5
out_filename = f'KDE_Ex_Data_{wh_err:s}_nrep_{n_rep:.0f}_nmax_{n_max:.0f}_dmax_{d_max:.0f}.pkl'
with open(figpath+out_filename,'rb') as myfile: 
    wh_err,n_densities,n_dim,n_samplers,n_n,dim_list,n_list,yplot,rhoexact,rhoapp,err_out_dict,pp_wh_med = pickle.load(myfile) #load in all the data

# %% [markdown]
# ### Plot densities and their approximations

# %%
for ll in range(n_n):
    n = n_list[ll]
    for ii in range(n_densities):  #iterate over different f and corresponding densities
        fig,ax = plt.subplots(1,n_dim,figsize = (15,5))
        for kk in range(n_dim):  #iterate over different dimensions
            d = dim_list[kk]
            dens_kwargs["d"] = d
            if (ex_densities[ii]["d_allowed"] == [float('inf')]) or any(d == dd for dd in ex_densities[ii]["d_allowed"]):
                ax[kk].plot(yplot[ii,kk,:], rhoexact[ii,kk,:], label = "true density")
                ax[kk].set_title(f'{ex_densities[ii]["name"](**dens_kwargs):s}, $n = {n:.0f}$')
                ax[kk].set_xlabel("$y$")
                ax[kk].set_ylabel("probability density")  
                for jj in range(n_samplers):  #iterate over different sampling methods
                    pp_plot = pp_wh_med[ii,jj,kk,ll]
                    ax[kk].plot(yplot[ii,kk,:],rhoapp[ii,jj,kk,ll,:], 
                            label = f'{samplers[jj]["sample_name"]}, {wh_err:s} = {best_err[ii,jj,kk,ll]:0.1e}')
                ax[kk].legend(loc="lower center")
        figfilename = f'KDE_Ex_Data_mae_{ex_densities[ii]["name"](**dens_kwargs):s}_nrep_{n_rep:.0f}_n_{n:.0f}_dmax_{d_max:.0f}.{fig_format:s}'
        #fig.savefig(figpath+f'KDE_Ex_Data_mae_{ex_densities[ii]["name"](**dens_kwargs):s}_n_{n:.0f}.eps',format='eps',bbox_inches='tight')        
        fig.savefig(figpath+figfilename,format=fig_format,bbox_inches='tight')

# %% [markdown]
# ### Plot error vs. n

# %% [markdown]
# ### Plot h vs. n

# %% [markdown]
# ## Run numerical experiments and store the data

# %%
nplot = 500 #number of points to plot the KDE at
wh_err = "mae"
n_rep = 15 #number of replications

dens_kwargs = {"d" : 1, "coord_wts" : np.array(range(1,11))**-2.}
dim_list = np.array([1, 2, 5])
n_list = 2**np.arange(6,10,dtype=int)
bandwidth_list = 2.**np.arange(-10,1,1)
n_densities = len(ex_densities)  #number of cases of f and densities
n_samplers = len(samplers)  #number of samplers
n_dim = dim_list.shape[0]  #number of dimensions
n_n = n_list.shape[0]  #number of sample sizes
n_bandwidth = bandwidth_list.shape[0]  #number of bandwidths
d_max = dim_list.max()
n_max = n_list.max()

## Initialize large arrays
rhoexact = np.zeros((n_densities,n_dim,nplot))
yplot = np.zeros((n_densities,n_dim,nplot))
rhoapp = np.zeros((n_densities,n_samplers,n_dim,n_n,nplot))
rhoapp_ppmm = np.zeros((n_rep,n_bandwidth,nplot))
err_out_dict = {(ii,jj,kk,ll) : 
        0 for ii in range(n_densities) for jj in range(n_samplers) for kk in range(n_dim) for ll in range(n_n)}
err_out_dict_pp = {pp : 0 for pp in range(n_rep)}
x_all = np.zeros((n_samplers,n_rep,n_max,d_max))   
ypts = np.zeros((n_rep,n_max))
pp_wh_med = np.zeros((n_densities,n_samplers,n_dim,n_n))
best_err = pp_wh_med
best_err_pp = np.zeros(n_rep)


for ii in range(n_densities):  #iterate over different f and corresponding densities
    for jj in range(n_samplers):            # construct the IID and LD nodes
        for pp in range(n_rep):              # n_rep repetitions
            x_all[jj,pp,:,:] = samplers[jj]["gen_sample"](d_max,n_max) 
    for kk in range(n_dim):  #iterate over dimensions
        d = dim_list[kk]
        if (ex_densities[ii]["d_allowed"] == [float('inf')]) or any(d == dd for dd in ex_densities[ii]["d_allowed"]):
            dens_kwargs["d"] = d  #update the dimension
            plt_domain = ex_densities[ii]["y_plt_domain"](**dens_kwargs) 
            print(plt_domain)
            yplot[ii,kk,:] = np.linspace(plt_domain[0],plt_domain[1],nplot)
            rhoexact[ii,kk,:] = ex_densities[ii]["density"](yplot[ii,kk,:],**dens_kwargs)
            h_list = np.diff(plt_domain)[0]*bandwidth_list
            #print(h_list)
            print(yplot[ii,kk,:])
            kernel = {"name" : "Gauss", "bandwidth" : 1, "domain" : ex_densities[ii]["y_domain"](**dens_kwargs)}
            for jj in range(n_samplers):  #iterate over sampling methods
                print(f"density #{ii:.0f}, dimension = {d:.0f}, sampler #{jj:.0f}")
                for pp in range(n_rep):  #iterate over replications
                    ypts[pp,:] = ex_densities[ii]["f"](x_all[jj,pp,:n_max,:d],**dens_kwargs)  #construct all data points for all repetitions                    
                for ll in range(n_n):  #iterate over sample sizes
                    n = n_list[ll]
                    for pp in range(n_rep):  #iterate over replications
                        for mm in range(n_bandwidth):  #iterate over different bandwidths 
                            kernel["bandwidth"] = h_list[mm]
                            rhoapp_ppmm[pp,mm,:] = kde(ypts[pp,:n],yplot[ii,kk,:],kernel)  #kde estimate
                        err_out_dict_pp[pp] = error_rho(rhoexact[ii,kk,:],rhoapp_ppmm[pp,:,:],h_list,kind_of_err = [wh_err])  #optimize bandwidth
                        best_err_pp[pp] = err_out_dict_pp[pp][wh_err][2]
                    #print(best_err)
                    pp_where = np.argsort(best_err_pp)[best_err_pp.shape[0]//2]
                    #print(pp_where)
                    pp_wh_med[ii,jj,kk,ll] = pp_where
                    #print(pp_where)
                    best_err[ii,jj,kk,ll] = best_err_pp[pp_where]
                    err_out_dict[ii,jj,kk,ll] = err_out_dict_pp[pp_where]
                    rhoapp[ii,jj,kk,ll,:] = rhoapp_ppmm[pp_where,err_out_dict_pp[pp_where][wh_err][0]]

out_filename = f'KDE_Ex_Data_{wh_err:s}_nrep_{n_rep:.0f}_nmax_{n_max:.0f}_dmax_{d_max:.0f}.pkl'
with open(figpath+out_filename,'wb') as myfile: 
    pickle.dump([wh_err,n_densities,n_dim,n_samplers,n_n,dim_list,n_list,yplot,rhoexact,rhoapp,err_out_dict,pp_wh_med],myfile)  #save numerical output as a pickle file
# Out:
# [-0.1  1.1]
# [-1.00000000e-01 -9.75951904e-02 -9.51903808e-02 -9.27855711e-02
#  -9.03807615e-02 -8.79759519e-02 -8.55711423e-02 -8.31663327e-02
#  -8.07615230e-02 -7.83567134e-02 -7.59519038e-02 -7.35470942e-02
#  -7.11422846e-02 -6.87374749e-02 -6.63326653e-02 -6.39278557e-02
#  -6.15230461e-02 -5.91182365e-02 -5.67134269e-02 -5.43086172e-02
#  -5.19038076e-02 -4.94989980e-02 -4.70941884e-02 -4.46893788e-02
#  -4.22845691e-02 -3.98797595e-02 -3.74749499e-02 -3.50701403e-02
#  -3.26653307e-02 -3.02605210e-02 -2.78557114e-02 -2.54509018e-02
#  -2.30460922e-02 -2.06412826e-02 -1.82364729e-02 -1.58316633e-02
#  -1.34268537e-02 -1.10220441e-02 -8.61723447e-03 -6.21242485e-03
#  -3.80761523e-03 -1.40280561e-03  1.00200401e-03  3.40681363e-03
#   5.81162325e-03  8.21643287e-03  1.06212425e-02  1.30260521e-02
#   1.54308617e-02  1.78356713e-02  2.02404810e-02  2.26452906e-02
#   2.50501002e-02  2.74549098e-02  2.98597194e-02  3.22645291e-02
#   3.46693387e-02  3.70741483e-02  3.94789579e-02  4.18837675e-02
#   4.42885772e-02  4.66933868e-02  4.90981964e-02  5.15030060e-02
#   5.39078156e-02  5.63126253e-02  5.87174349e-02  6.11222445e-02
#   6.35270541e-02  6.59318637e-02  6.83366733e-02  7.07414830e-02
#   7.31462926e-02  7.55511022e-02  7.79559118e-02  8.03607214e-02
#   8.27655311e-02  8.51703407e-02  8.75751503e-02  8.99799599e-02
#   9.23847695e-02  9.47895792e-02  9.71943888e-02  9.95991984e-02
#   1.02004008e-01  1.04408818e-01  1.06813627e-01  1.09218437e-01
#   1.11623246e-01  1.14028056e-01  1.16432866e-01  1.18837675e-01
#   1.21242485e-01  1.23647295e-01  1.26052104e-01  1.28456914e-01
#   1.30861723e-01  1.33266533e-01  1.35671343e-01  1.38076152e-01
#   1.40480962e-01  1.42885772e-01  1.45290581e-01  1.47695391e-01
#   1.50100200e-01  1.52505010e-01  1.54909820e-01  1.57314629e-01
#   1.59719439e-01  1.62124248e-01  1.64529058e-01  1.66933868e-01
#   1.69338677e-01  1.71743487e-01  1.74148297e-01  1.76553106e-01
#   1.78957916e-01  1.81362725e-01  1.83767535e-01  1.86172345e-01
#   1.88577154e-01  1.90981964e-01  1.93386774e-01  1.95791583e-01
#   1.98196393e-01  2.00601202e-01  2.03006012e-01  2.05410822e-01
#   2.07815631e-01  2.10220441e-01  2.12625251e-01  2.15030060e-01
#   2.17434870e-01  2.19839679e-01  2.22244489e-01  2.24649299e-01
#   2.27054108e-01  2.29458918e-01  2.31863727e-01  2.34268537e-01
#   2.36673347e-01  2.39078156e-01  2.41482966e-01  2.43887776e-01
#   2.46292585e-01  2.48697395e-01  2.51102204e-01  2.53507014e-01
#   2.55911824e-01  2.58316633e-01  2.60721443e-01  2.63126253e-01
#   2.65531062e-01  2.67935872e-01  2.70340681e-01  2.72745491e-01
#   2.75150301e-01  2.77555110e-01  2.79959920e-01  2.82364729e-01
#   2.84769539e-01  2.87174349e-01  2.89579158e-01  2.91983968e-01
#   2.94388778e-01  2.96793587e-01  2.99198397e-01  3.01603206e-01
#   3.04008016e-01  3.06412826e-01  3.08817635e-01  3.11222445e-01
#   3.13627255e-01  3.16032064e-01  3.18436874e-01  3.20841683e-01
#   3.23246493e-01  3.25651303e-01  3.28056112e-01  3.30460922e-01
#   3.32865731e-01  3.35270541e-01  3.37675351e-01  3.40080160e-01
#   3.42484970e-01  3.44889780e-01  3.47294589e-01  3.49699399e-01
#   3.52104208e-01  3.54509018e-01  3.56913828e-01  3.59318637e-01
#   3.61723447e-01  3.64128257e-01  3.66533066e-01  3.68937876e-01
#   3.71342685e-01  3.73747495e-01  3.76152305e-01  3.78557114e-01
#   3.80961924e-01  3.83366733e-01  3.85771543e-01  3.88176353e-01
#   3.90581162e-01  3.92985972e-01  3.95390782e-01  3.97795591e-01
#   4.00200401e-01  4.02605210e-01  4.05010020e-01  4.07414830e-01
#   4.09819639e-01  4.12224449e-01  4.14629259e-01  4.17034068e-01
#   4.19438878e-01  4.21843687e-01  4.24248497e-01  4.26653307e-01
#   4.29058116e-01  4.31462926e-01  4.33867735e-01  4.36272545e-01
#   4.38677355e-01  4.41082164e-01  4.43486974e-01  4.45891784e-01
#   4.48296593e-01  4.50701403e-01  4.53106212e-01  4.55511022e-01
#   4.57915832e-01  4.60320641e-01  4.62725451e-01  4.65130261e-01
#   4.67535070e-01  4.69939880e-01  4.72344689e-01  4.74749499e-01
#   4.77154309e-01  4.79559118e-01  4.81963928e-01  4.84368737e-01
#   4.86773547e-01  4.89178357e-01  4.91583166e-01  4.93987976e-01
#   4.96392786e-01  4.98797595e-01  5.01202405e-01  5.03607214e-01
#   5.06012024e-01  5.08416834e-01  5.10821643e-01  5.13226453e-01
#   5.15631263e-01  5.18036072e-01  5.20440882e-01  5.22845691e-01
#   5.25250501e-01  5.27655311e-01  5.30060120e-01  5.32464930e-01
#   5.34869739e-01  5.37274549e-01  5.39679359e-01  5.42084168e-01
#   5.44488978e-01  5.46893788e-01  5.49298597e-01  5.51703407e-01
#   5.54108216e-01  5.56513026e-01  5.58917836e-01  5.61322645e-01
#   5.63727455e-01  5.66132265e-01  5.68537074e-01  5.70941884e-01
#   5.73346693e-01  5.75751503e-01  5.78156313e-01  5.80561122e-01
#   5.82965932e-01  5.85370741e-01  5.87775551e-01  5.90180361e-01
#   5.92585170e-01  5.94989980e-01  5.97394790e-01  5.99799599e-01
#   6.02204409e-01  6.04609218e-01  6.07014028e-01  6.09418838e-01
#   6.11823647e-01  6.14228457e-01  6.16633267e-01  6.19038076e-01
#   6.21442886e-01  6.23847695e-01  6.26252505e-01  6.28657315e-01
#   6.31062124e-01  6.33466934e-01  6.35871743e-01  6.38276553e-01
#   6.40681363e-01  6.43086172e-01  6.45490982e-01  6.47895792e-01
#   6.50300601e-01  6.52705411e-01  6.55110220e-01  6.57515030e-01
#   6.59919840e-01  6.62324649e-01  6.64729459e-01  6.67134269e-01
#   6.69539078e-01  6.71943888e-01  6.74348697e-01  6.76753507e-01
#   6.79158317e-01  6.81563126e-01  6.83967936e-01  6.86372745e-01
#   6.88777555e-01  6.91182365e-01  6.93587174e-01  6.95991984e-01
#   6.98396794e-01  7.00801603e-01  7.03206413e-01  7.05611222e-01
#   7.08016032e-01  7.10420842e-01  7.12825651e-01  7.15230461e-01
#   7.17635271e-01  7.20040080e-01  7.22444890e-01  7.24849699e-01
#   7.27254509e-01  7.29659319e-01  7.32064128e-01  7.34468938e-01
#   7.36873747e-01  7.39278557e-01  7.41683367e-01  7.44088176e-01
#   7.46492986e-01  7.48897796e-01  7.51302605e-01  7.53707415e-01
#   7.56112224e-01  7.58517034e-01  7.60921844e-01  7.63326653e-01
#   7.65731463e-01  7.68136273e-01  7.70541082e-01  7.72945892e-01
#   7.75350701e-01  7.77755511e-01  7.80160321e-01  7.82565130e-01
#   7.84969940e-01  7.87374749e-01  7.89779559e-01  7.92184369e-01
#   7.94589178e-01  7.96993988e-01  7.99398798e-01  8.01803607e-01
#   8.04208417e-01  8.06613226e-01  8.09018036e-01  8.11422846e-01
#   8.13827655e-01  8.16232465e-01  8.18637275e-01  8.21042084e-01
#   8.23446894e-01  8.25851703e-01  8.28256513e-01  8.30661323e-01
#   8.33066132e-01  8.35470942e-01  8.37875752e-01  8.40280561e-01
#   8.42685371e-01  8.45090180e-01  8.47494990e-01  8.49899800e-01
#   8.52304609e-01  8.54709419e-01  8.57114228e-01  8.59519038e-01
#   8.61923848e-01  8.64328657e-01  8.66733467e-01  8.69138277e-01
#   8.71543086e-01  8.73947896e-01  8.76352705e-01  8.78757515e-01
#   8.81162325e-01  8.83567134e-01  8.85971944e-01  8.88376754e-01
#   8.90781563e-01  8.93186373e-01  8.95591182e-01  8.97995992e-01
#   9.00400802e-01  9.02805611e-01  9.05210421e-01  9.07615230e-01
#   9.10020040e-01  9.12424850e-01  9.14829659e-01  9.17234469e-01
#   9.19639279e-01  9.22044088e-01  9.24448898e-01  9.26853707e-01
#   9.29258517e-01  9.31663327e-01  9.34068136e-01  9.36472946e-01
#   9.38877756e-01  9.41282565e-01  9.43687375e-01  9.46092184e-01
#   9.48496994e-01  9.50901804e-01  9.53306613e-01  9.55711423e-01
#   9.58116232e-01  9.60521042e-01  9.62925852e-01  9.65330661e-01
#   9.67735471e-01  9.70140281e-01  9.72545090e-01  9.74949900e-01
#   9.77354709e-01  9.79759519e-01  9.82164329e-01  9.84569138e-01
#   9.86973948e-01  9.89378758e-01  9.91783567e-01  9.94188377e-01
#   9.96593186e-01  9.98997996e-01  1.00140281e+00  1.00380762e+00
#   1.00621242e+00  1.00861723e+00  1.01102204e+00  1.01342685e+00
#   1.01583166e+00  1.01823647e+00  1.02064128e+00  1.02304609e+00
#   1.02545090e+00  1.02785571e+00  1.03026052e+00  1.03266533e+00
#   1.03507014e+00  1.03747495e+00  1.03987976e+00  1.04228457e+00
#   1.04468938e+00  1.04709419e+00  1.04949900e+00  1.05190381e+00
#   1.05430862e+00  1.05671343e+00  1.05911824e+00  1.06152305e+00
#   1.06392786e+00  1.06633267e+00  1.06873747e+00  1.07114228e+00
#   1.07354709e+00  1.07595190e+00  1.07835671e+00  1.08076152e+00
#   1.08316633e+00  1.08557114e+00  1.08797595e+00  1.09038076e+00
#   1.09278557e+00  1.09519038e+00  1.09759519e+00  1.10000000e+00]
# density #0, dimension = 1, sampler #0
# density #0, dimension = 1, sampler #1
# density #0, dimension = 1, sampler #2
# density #0, dimension = 1, sampler #3
# [-0.1  2.1]
# [-1.00000000e-01 -9.55911824e-02 -9.11823647e-02 -8.67735471e-02
#  -8.23647295e-02 -7.79559118e-02 -7.35470942e-02 -6.91382766e-02
#  -6.47294589e-02 -6.03206413e-02 -5.59118236e-02 -5.15030060e-02
#  -4.70941884e-02 -4.26853707e-02 -3.82765531e-02 -3.38677355e-02
#  -2.94589178e-02 -2.50501002e-02 -2.06412826e-02 -1.62324649e-02
#  -1.18236473e-02 -7.41482966e-03 -3.00601202e-03  1.40280561e-03
#   5.81162325e-03  1.02204409e-02  1.46292585e-02  1.90380762e-02
#   2.34468938e-02  2.78557114e-02  3.22645291e-02  3.66733467e-02
#   4.10821643e-02  4.54909820e-02  4.98997996e-02  5.43086172e-02
#   5.87174349e-02  6.31262525e-02  6.75350701e-02  7.19438878e-02
#   7.63527054e-02  8.07615230e-02  8.51703407e-02  8.95791583e-02
#   9.39879760e-02  9.83967936e-02  1.02805611e-01  1.07214429e-01
#   1.11623246e-01  1.16032064e-01  1.20440882e-01  1.24849699e-01
#   1.29258517e-01  1.33667335e-01  1.38076152e-01  1.42484970e-01
#   1.46893788e-01  1.51302605e-01  1.55711423e-01  1.60120240e-01
#   1.64529058e-01  1.68937876e-01  1.73346693e-01  1.77755511e-01
#   1.82164329e-01  1.86573146e-01  1.90981964e-01  1.95390782e-01
#   1.99799599e-01  2.04208417e-01  2.08617234e-01  2.13026052e-01
#   2.17434870e-01  2.21843687e-01  2.26252505e-01  2.30661323e-01
#   2.35070140e-01  2.39478958e-01  2.43887776e-01  2.48296593e-01
#   2.52705411e-01  2.57114228e-01  2.61523046e-01  2.65931864e-01
#   2.70340681e-01  2.74749499e-01  2.79158317e-01  2.83567134e-01
#   2.87975952e-01  2.92384770e-01  2.96793587e-01  3.01202405e-01
#   3.05611222e-01  3.10020040e-01  3.14428858e-01  3.18837675e-01
#   3.23246493e-01  3.27655311e-01  3.32064128e-01  3.36472946e-01
#   3.40881764e-01  3.45290581e-01  3.49699399e-01  3.54108216e-01
#   3.58517034e-01  3.62925852e-01  3.67334669e-01  3.71743487e-01
#   3.76152305e-01  3.80561122e-01  3.84969940e-01  3.89378758e-01
#   3.93787575e-01  3.98196393e-01  4.02605210e-01  4.07014028e-01
#   4.11422846e-01  4.15831663e-01  4.20240481e-01  4.24649299e-01
#   4.29058116e-01  4.33466934e-01  4.37875752e-01  4.42284569e-01
#   4.46693387e-01  4.51102204e-01  4.55511022e-01  4.59919840e-01
#   4.64328657e-01  4.68737475e-01  4.73146293e-01  4.77555110e-01
#   4.81963928e-01  4.86372745e-01  4.90781563e-01  4.95190381e-01
#   4.99599198e-01  5.04008016e-01  5.08416834e-01  5.12825651e-01
#   5.17234469e-01  5.21643287e-01  5.26052104e-01  5.30460922e-01
#   5.34869739e-01  5.39278557e-01  5.43687375e-01  5.48096192e-01
#   5.52505010e-01  5.56913828e-01  5.61322645e-01  5.65731463e-01
#   5.70140281e-01  5.74549098e-01  5.78957916e-01  5.83366733e-01
#   5.87775551e-01  5.92184369e-01  5.96593186e-01  6.01002004e-01
#   6.05410822e-01  6.09819639e-01  6.14228457e-01  6.18637275e-01
#   6.23046092e-01  6.27454910e-01  6.31863727e-01  6.36272545e-01
#   6.40681363e-01  6.45090180e-01  6.49498998e-01  6.53907816e-01
#   6.58316633e-01  6.62725451e-01  6.67134269e-01  6.71543086e-01
#   6.75951904e-01  6.80360721e-01  6.84769539e-01  6.89178357e-01
#   6.93587174e-01  6.97995992e-01  7.02404810e-01  7.06813627e-01
#   7.11222445e-01  7.15631263e-01  7.20040080e-01  7.24448898e-01
#   7.28857715e-01  7.33266533e-01  7.37675351e-01  7.42084168e-01
#   7.46492986e-01  7.50901804e-01  7.55310621e-01  7.59719439e-01
#   7.64128257e-01  7.68537074e-01  7.72945892e-01  7.77354709e-01
#   7.81763527e-01  7.86172345e-01  7.90581162e-01  7.94989980e-01
#   7.99398798e-01  8.03807615e-01  8.08216433e-01  8.12625251e-01
#   8.17034068e-01  8.21442886e-01  8.25851703e-01  8.30260521e-01
#   8.34669339e-01  8.39078156e-01  8.43486974e-01  8.47895792e-01
#   8.52304609e-01  8.56713427e-01  8.61122244e-01  8.65531062e-01
#   8.69939880e-01  8.74348697e-01  8.78757515e-01  8.83166333e-01
#   8.87575150e-01  8.91983968e-01  8.96392786e-01  9.00801603e-01
#   9.05210421e-01  9.09619238e-01  9.14028056e-01  9.18436874e-01
#   9.22845691e-01  9.27254509e-01  9.31663327e-01  9.36072144e-01
#   9.40480962e-01  9.44889780e-01  9.49298597e-01  9.53707415e-01
#   9.58116232e-01  9.62525050e-01  9.66933868e-01  9.71342685e-01
#   9.75751503e-01  9.80160321e-01  9.84569138e-01  9.88977956e-01
#   9.93386774e-01  9.97795591e-01  1.00220441e+00  1.00661323e+00
#   1.01102204e+00  1.01543086e+00  1.01983968e+00  1.02424850e+00
#   1.02865731e+00  1.03306613e+00  1.03747495e+00  1.04188377e+00
#   1.04629259e+00  1.05070140e+00  1.05511022e+00  1.05951904e+00
#   1.06392786e+00  1.06833667e+00  1.07274549e+00  1.07715431e+00
#   1.08156313e+00  1.08597194e+00  1.09038076e+00  1.09478958e+00
#   1.09919840e+00  1.10360721e+00  1.10801603e+00  1.11242485e+00
#   1.11683367e+00  1.12124248e+00  1.12565130e+00  1.13006012e+00
#   1.13446894e+00  1.13887776e+00  1.14328657e+00  1.14769539e+00
#   1.15210421e+00  1.15651303e+00  1.16092184e+00  1.16533066e+00
#   1.16973948e+00  1.17414830e+00  1.17855711e+00  1.18296593e+00
#   1.18737475e+00  1.19178357e+00  1.19619238e+00  1.20060120e+00
#   1.20501002e+00  1.20941884e+00  1.21382766e+00  1.21823647e+00
#   1.22264529e+00  1.22705411e+00  1.23146293e+00  1.23587174e+00
#   1.24028056e+00  1.24468938e+00  1.24909820e+00  1.25350701e+00
#   1.25791583e+00  1.26232465e+00  1.26673347e+00  1.27114228e+00
#   1.27555110e+00  1.27995992e+00  1.28436874e+00  1.28877756e+00
#   1.29318637e+00  1.29759519e+00  1.30200401e+00  1.30641283e+00
#   1.31082164e+00  1.31523046e+00  1.31963928e+00  1.32404810e+00
#   1.32845691e+00  1.33286573e+00  1.33727455e+00  1.34168337e+00
#   1.34609218e+00  1.35050100e+00  1.35490982e+00  1.35931864e+00
#   1.36372745e+00  1.36813627e+00  1.37254509e+00  1.37695391e+00
#   1.38136273e+00  1.38577154e+00  1.39018036e+00  1.39458918e+00
#   1.39899800e+00  1.40340681e+00  1.40781563e+00  1.41222445e+00
#   1.41663327e+00  1.42104208e+00  1.42545090e+00  1.42985972e+00
#   1.43426854e+00  1.43867735e+00  1.44308617e+00  1.44749499e+00
#   1.45190381e+00  1.45631263e+00  1.46072144e+00  1.46513026e+00
#   1.46953908e+00  1.47394790e+00  1.47835671e+00  1.48276553e+00
#   1.48717435e+00  1.49158317e+00  1.49599198e+00  1.50040080e+00
#   1.50480962e+00  1.50921844e+00  1.51362725e+00  1.51803607e+00
#   1.52244489e+00  1.52685371e+00  1.53126253e+00  1.53567134e+00
#   1.54008016e+00  1.54448898e+00  1.54889780e+00  1.55330661e+00
#   1.55771543e+00  1.56212425e+00  1.56653307e+00  1.57094188e+00
#   1.57535070e+00  1.57975952e+00  1.58416834e+00  1.58857715e+00
#   1.59298597e+00  1.59739479e+00  1.60180361e+00  1.60621242e+00
#   1.61062124e+00  1.61503006e+00  1.61943888e+00  1.62384770e+00
#   1.62825651e+00  1.63266533e+00  1.63707415e+00  1.64148297e+00
#   1.64589178e+00  1.65030060e+00  1.65470942e+00  1.65911824e+00
#   1.66352705e+00  1.66793587e+00  1.67234469e+00  1.67675351e+00
#   1.68116232e+00  1.68557114e+00  1.68997996e+00  1.69438878e+00
#   1.69879760e+00  1.70320641e+00  1.70761523e+00  1.71202405e+00
#   1.71643287e+00  1.72084168e+00  1.72525050e+00  1.72965932e+00
#   1.73406814e+00  1.73847695e+00  1.74288577e+00  1.74729459e+00
#   1.75170341e+00  1.75611222e+00  1.76052104e+00  1.76492986e+00
#   1.76933868e+00  1.77374749e+00  1.77815631e+00  1.78256513e+00
#   1.78697395e+00  1.79138277e+00  1.79579158e+00  1.80020040e+00
#   1.80460922e+00  1.80901804e+00  1.81342685e+00  1.81783567e+00
#   1.82224449e+00  1.82665331e+00  1.83106212e+00  1.83547094e+00
#   1.83987976e+00  1.84428858e+00  1.84869739e+00  1.85310621e+00
#   1.85751503e+00  1.86192385e+00  1.86633267e+00  1.87074148e+00
#   1.87515030e+00  1.87955912e+00  1.88396794e+00  1.88837675e+00
#   1.89278557e+00  1.89719439e+00  1.90160321e+00  1.90601202e+00
#   1.91042084e+00  1.91482966e+00  1.91923848e+00  1.92364729e+00
#   1.92805611e+00  1.93246493e+00  1.93687375e+00  1.94128257e+00
#   1.94569138e+00  1.95010020e+00  1.95450902e+00  1.95891784e+00
#   1.96332665e+00  1.96773547e+00  1.97214429e+00  1.97655311e+00
#   1.98096192e+00  1.98537074e+00  1.98977956e+00  1.99418838e+00
#   1.99859719e+00  2.00300601e+00  2.00741483e+00  2.01182365e+00
#   2.01623246e+00  2.02064128e+00  2.02505010e+00  2.02945892e+00
#   2.03386774e+00  2.03827655e+00  2.04268537e+00  2.04709419e+00
#   2.05150301e+00  2.05591182e+00  2.06032064e+00  2.06472946e+00
#   2.06913828e+00  2.07354709e+00  2.07795591e+00  2.08236473e+00
#   2.08677355e+00  2.09118236e+00  2.09559118e+00  2.10000000e+00]
# density #0, dimension = 2, sampler #0
# density #0, dimension = 2, sampler #1
# density #0, dimension = 2, sampler #2
# density #0, dimension = 2, sampler #3
# [-0.1  5.1]
# [-1.00000000e-01 -8.95791583e-02 -7.91583166e-02 -6.87374749e-02
#  -5.83166333e-02 -4.78957916e-02 -3.74749499e-02 -2.70541082e-02
#  -1.66332665e-02 -6.21242485e-03  4.20841683e-03  1.46292585e-02
#   2.50501002e-02  3.54709419e-02  4.58917836e-02  5.63126253e-02
#   6.67334669e-02  7.71543086e-02  8.75751503e-02  9.79959920e-02
#   1.08416834e-01  1.18837675e-01  1.29258517e-01  1.39679359e-01
#   1.50100200e-01  1.60521042e-01  1.70941884e-01  1.81362725e-01
#   1.91783567e-01  2.02204409e-01  2.12625251e-01  2.23046092e-01
#   2.33466934e-01  2.43887776e-01  2.54308617e-01  2.64729459e-01
#   2.75150301e-01  2.85571142e-01  2.95991984e-01  3.06412826e-01
#   3.16833667e-01  3.27254509e-01  3.37675351e-01  3.48096192e-01
#   3.58517034e-01  3.68937876e-01  3.79358717e-01  3.89779559e-01
#   4.00200401e-01  4.10621242e-01  4.21042084e-01  4.31462926e-01
#   4.41883768e-01  4.52304609e-01  4.62725451e-01  4.73146293e-01
#   4.83567134e-01  4.93987976e-01  5.04408818e-01  5.14829659e-01
#   5.25250501e-01  5.35671343e-01  5.46092184e-01  5.56513026e-01
#   5.66933868e-01  5.77354709e-01  5.87775551e-01  5.98196393e-01
#   6.08617234e-01  6.19038076e-01  6.29458918e-01  6.39879760e-01
#   6.50300601e-01  6.60721443e-01  6.71142285e-01  6.81563126e-01
#   6.91983968e-01  7.02404810e-01  7.12825651e-01  7.23246493e-01
#   7.33667335e-01  7.44088176e-01  7.54509018e-01  7.64929860e-01
#   7.75350701e-01  7.85771543e-01  7.96192385e-01  8.06613226e-01
#   8.17034068e-01  8.27454910e-01  8.37875752e-01  8.48296593e-01
#   8.58717435e-01  8.69138277e-01  8.79559118e-01  8.89979960e-01
#   9.00400802e-01  9.10821643e-01  9.21242485e-01  9.31663327e-01
#   9.42084168e-01  9.52505010e-01  9.62925852e-01  9.73346693e-01
#   9.83767535e-01  9.94188377e-01  1.00460922e+00  1.01503006e+00
#   1.02545090e+00  1.03587174e+00  1.04629259e+00  1.05671343e+00
#   1.06713427e+00  1.07755511e+00  1.08797595e+00  1.09839679e+00
#   1.10881764e+00  1.11923848e+00  1.12965932e+00  1.14008016e+00
#   1.15050100e+00  1.16092184e+00  1.17134269e+00  1.18176353e+00
#   1.19218437e+00  1.20260521e+00  1.21302605e+00  1.22344689e+00
#   1.23386774e+00  1.24428858e+00  1.25470942e+00  1.26513026e+00
#   1.27555110e+00  1.28597194e+00  1.29639279e+00  1.30681363e+00
#   1.31723447e+00  1.32765531e+00  1.33807615e+00  1.34849699e+00
#   1.35891784e+00  1.36933868e+00  1.37975952e+00  1.39018036e+00
#   1.40060120e+00  1.41102204e+00  1.42144289e+00  1.43186373e+00
#   1.44228457e+00  1.45270541e+00  1.46312625e+00  1.47354709e+00
#   1.48396794e+00  1.49438878e+00  1.50480962e+00  1.51523046e+00
#   1.52565130e+00  1.53607214e+00  1.54649299e+00  1.55691383e+00
#   1.56733467e+00  1.57775551e+00  1.58817635e+00  1.59859719e+00
#   1.60901804e+00  1.61943888e+00  1.62985972e+00  1.64028056e+00
#   1.65070140e+00  1.66112224e+00  1.67154309e+00  1.68196393e+00
#   1.69238477e+00  1.70280561e+00  1.71322645e+00  1.72364729e+00
#   1.73406814e+00  1.74448898e+00  1.75490982e+00  1.76533066e+00
#   1.77575150e+00  1.78617234e+00  1.79659319e+00  1.80701403e+00
#   1.81743487e+00  1.82785571e+00  1.83827655e+00  1.84869739e+00
#   1.85911824e+00  1.86953908e+00  1.87995992e+00  1.89038076e+00
#   1.90080160e+00  1.91122244e+00  1.92164329e+00  1.93206413e+00
#   1.94248497e+00  1.95290581e+00  1.96332665e+00  1.97374749e+00
#   1.98416834e+00  1.99458918e+00  2.00501002e+00  2.01543086e+00
#   2.02585170e+00  2.03627255e+00  2.04669339e+00  2.05711423e+00
#   2.06753507e+00  2.07795591e+00  2.08837675e+00  2.09879760e+00
#   2.10921844e+00  2.11963928e+00  2.13006012e+00  2.14048096e+00
#   2.15090180e+00  2.16132265e+00  2.17174349e+00  2.18216433e+00
#   2.19258517e+00  2.20300601e+00  2.21342685e+00  2.22384770e+00
#   2.23426854e+00  2.24468938e+00  2.25511022e+00  2.26553106e+00
#   2.27595190e+00  2.28637275e+00  2.29679359e+00  2.30721443e+00
#   2.31763527e+00  2.32805611e+00  2.33847695e+00  2.34889780e+00
#   2.35931864e+00  2.36973948e+00  2.38016032e+00  2.39058116e+00
#   2.40100200e+00  2.41142285e+00  2.42184369e+00  2.43226453e+00
#   2.44268537e+00  2.45310621e+00  2.46352705e+00  2.47394790e+00
#   2.48436874e+00  2.49478958e+00  2.50521042e+00  2.51563126e+00
#   2.52605210e+00  2.53647295e+00  2.54689379e+00  2.55731463e+00
#   2.56773547e+00  2.57815631e+00  2.58857715e+00  2.59899800e+00
#   2.60941884e+00  2.61983968e+00  2.63026052e+00  2.64068136e+00
#   2.65110220e+00  2.66152305e+00  2.67194389e+00  2.68236473e+00
#   2.69278557e+00  2.70320641e+00  2.71362725e+00  2.72404810e+00
#   2.73446894e+00  2.74488978e+00  2.75531062e+00  2.76573146e+00
#   2.77615230e+00  2.78657315e+00  2.79699399e+00  2.80741483e+00
#   2.81783567e+00  2.82825651e+00  2.83867735e+00  2.84909820e+00
#   2.85951904e+00  2.86993988e+00  2.88036072e+00  2.89078156e+00
#   2.90120240e+00  2.91162325e+00  2.92204409e+00  2.93246493e+00
#   2.94288577e+00  2.95330661e+00  2.96372745e+00  2.97414830e+00
#   2.98456914e+00  2.99498998e+00  3.00541082e+00  3.01583166e+00
#   3.02625251e+00  3.03667335e+00  3.04709419e+00  3.05751503e+00
#   3.06793587e+00  3.07835671e+00  3.08877756e+00  3.09919840e+00
#   3.10961924e+00  3.12004008e+00  3.13046092e+00  3.14088176e+00
#   3.15130261e+00  3.16172345e+00  3.17214429e+00  3.18256513e+00
#   3.19298597e+00  3.20340681e+00  3.21382766e+00  3.22424850e+00
#   3.23466934e+00  3.24509018e+00  3.25551102e+00  3.26593186e+00
#   3.27635271e+00  3.28677355e+00  3.29719439e+00  3.30761523e+00
#   3.31803607e+00  3.32845691e+00  3.33887776e+00  3.34929860e+00
#   3.35971944e+00  3.37014028e+00  3.38056112e+00  3.39098196e+00
#   3.40140281e+00  3.41182365e+00  3.42224449e+00  3.43266533e+00
#   3.44308617e+00  3.45350701e+00  3.46392786e+00  3.47434870e+00
#   3.48476954e+00  3.49519038e+00  3.50561122e+00  3.51603206e+00
#   3.52645291e+00  3.53687375e+00  3.54729459e+00  3.55771543e+00
#   3.56813627e+00  3.57855711e+00  3.58897796e+00  3.59939880e+00
#   3.60981964e+00  3.62024048e+00  3.63066132e+00  3.64108216e+00
#   3.65150301e+00  3.66192385e+00  3.67234469e+00  3.68276553e+00
#   3.69318637e+00  3.70360721e+00  3.71402806e+00  3.72444890e+00
#   3.73486974e+00  3.74529058e+00  3.75571142e+00  3.76613226e+00
#   3.77655311e+00  3.78697395e+00  3.79739479e+00  3.80781563e+00
#   3.81823647e+00  3.82865731e+00  3.83907816e+00  3.84949900e+00
#   3.85991984e+00  3.87034068e+00  3.88076152e+00  3.89118236e+00
#   3.90160321e+00  3.91202405e+00  3.92244489e+00  3.93286573e+00
#   3.94328657e+00  3.95370741e+00  3.96412826e+00  3.97454910e+00
#   3.98496994e+00  3.99539078e+00  4.00581162e+00  4.01623246e+00
#   4.02665331e+00  4.03707415e+00  4.04749499e+00  4.05791583e+00
#   4.06833667e+00  4.07875752e+00  4.08917836e+00  4.09959920e+00
#   4.11002004e+00  4.12044088e+00  4.13086172e+00  4.14128257e+00
#   4.15170341e+00  4.16212425e+00  4.17254509e+00  4.18296593e+00
#   4.19338677e+00  4.20380762e+00  4.21422846e+00  4.22464930e+00
#   4.23507014e+00  4.24549098e+00  4.25591182e+00  4.26633267e+00
#   4.27675351e+00  4.28717435e+00  4.29759519e+00  4.30801603e+00
#   4.31843687e+00  4.32885772e+00  4.33927856e+00  4.34969940e+00
#   4.36012024e+00  4.37054108e+00  4.38096192e+00  4.39138277e+00
#   4.40180361e+00  4.41222445e+00  4.42264529e+00  4.43306613e+00
#   4.44348697e+00  4.45390782e+00  4.46432866e+00  4.47474950e+00
#   4.48517034e+00  4.49559118e+00  4.50601202e+00  4.51643287e+00
#   4.52685371e+00  4.53727455e+00  4.54769539e+00  4.55811623e+00
#   4.56853707e+00  4.57895792e+00  4.58937876e+00  4.59979960e+00
#   4.61022044e+00  4.62064128e+00  4.63106212e+00  4.64148297e+00
#   4.65190381e+00  4.66232465e+00  4.67274549e+00  4.68316633e+00
#   4.69358717e+00  4.70400802e+00  4.71442886e+00  4.72484970e+00
#   4.73527054e+00  4.74569138e+00  4.75611222e+00  4.76653307e+00
#   4.77695391e+00  4.78737475e+00  4.79779559e+00  4.80821643e+00
#   4.81863727e+00  4.82905812e+00  4.83947896e+00  4.84989980e+00
#   4.86032064e+00  4.87074148e+00  4.88116232e+00  4.89158317e+00
#   4.90200401e+00  4.91242485e+00  4.92284569e+00  4.93326653e+00
#   4.94368737e+00  4.95410822e+00  4.96452906e+00  4.97494990e+00
#   4.98537074e+00  4.99579158e+00  5.00621242e+00  5.01663327e+00
#   5.02705411e+00  5.03747495e+00  5.04789579e+00  5.05831663e+00
#   5.06873747e+00  5.07915832e+00  5.08957916e+00  5.10000000e+00]
# density #0, dimension = 5, sampler #0
# density #0, dimension = 5, sampler #1
# density #0, dimension = 5, sampler #2
# density #0, dimension = 5, sampler #3
# [-3.  3.]
# [-3.         -2.98797595 -2.9759519  -2.96392786 -2.95190381 -2.93987976
#  -2.92785571 -2.91583166 -2.90380762 -2.89178357 -2.87975952 -2.86773547
#  -2.85571142 -2.84368737 -2.83166333 -2.81963928 -2.80761523 -2.79559118
#  -2.78356713 -2.77154309 -2.75951904 -2.74749499 -2.73547094 -2.72344689
#  -2.71142285 -2.6993988  -2.68737475 -2.6753507  -2.66332665 -2.65130261
#  -2.63927856 -2.62725451 -2.61523046 -2.60320641 -2.59118236 -2.57915832
#  -2.56713427 -2.55511022 -2.54308617 -2.53106212 -2.51903808 -2.50701403
#  -2.49498998 -2.48296593 -2.47094188 -2.45891784 -2.44689379 -2.43486974
#  -2.42284569 -2.41082164 -2.3987976  -2.38677355 -2.3747495  -2.36272545
#  -2.3507014  -2.33867735 -2.32665331 -2.31462926 -2.30260521 -2.29058116
#  -2.27855711 -2.26653307 -2.25450902 -2.24248497 -2.23046092 -2.21843687
#  -2.20641283 -2.19438878 -2.18236473 -2.17034068 -2.15831663 -2.14629259
#  -2.13426854 -2.12224449 -2.11022044 -2.09819639 -2.08617234 -2.0741483
#  -2.06212425 -2.0501002  -2.03807615 -2.0260521  -2.01402806 -2.00200401
#  -1.98997996 -1.97795591 -1.96593186 -1.95390782 -1.94188377 -1.92985972
#  -1.91783567 -1.90581162 -1.89378758 -1.88176353 -1.86973948 -1.85771543
#  -1.84569138 -1.83366733 -1.82164329 -1.80961924 -1.79759519 -1.78557114
#  -1.77354709 -1.76152305 -1.749499   -1.73747495 -1.7254509  -1.71342685
#  -1.70140281 -1.68937876 -1.67735471 -1.66533066 -1.65330661 -1.64128257
#  -1.62925852 -1.61723447 -1.60521042 -1.59318637 -1.58116232 -1.56913828
#  -1.55711423 -1.54509018 -1.53306613 -1.52104208 -1.50901804 -1.49699399
#  -1.48496994 -1.47294589 -1.46092184 -1.4488978  -1.43687375 -1.4248497
#  -1.41282565 -1.4008016  -1.38877756 -1.37675351 -1.36472946 -1.35270541
#  -1.34068136 -1.32865731 -1.31663327 -1.30460922 -1.29258517 -1.28056112
#  -1.26853707 -1.25651303 -1.24448898 -1.23246493 -1.22044088 -1.20841683
#  -1.19639279 -1.18436874 -1.17234469 -1.16032064 -1.14829659 -1.13627255
#  -1.1242485  -1.11222445 -1.1002004  -1.08817635 -1.0761523  -1.06412826
#  -1.05210421 -1.04008016 -1.02805611 -1.01603206 -1.00400802 -0.99198397
#  -0.97995992 -0.96793587 -0.95591182 -0.94388778 -0.93186373 -0.91983968
#  -0.90781563 -0.89579158 -0.88376754 -0.87174349 -0.85971944 -0.84769539
#  -0.83567134 -0.82364729 -0.81162325 -0.7995992  -0.78757515 -0.7755511
#  -0.76352705 -0.75150301 -0.73947896 -0.72745491 -0.71543086 -0.70340681
#  -0.69138277 -0.67935872 -0.66733467 -0.65531062 -0.64328657 -0.63126253
#  -0.61923848 -0.60721443 -0.59519038 -0.58316633 -0.57114228 -0.55911824
#  -0.54709419 -0.53507014 -0.52304609 -0.51102204 -0.498998   -0.48697395
#  -0.4749499  -0.46292585 -0.4509018  -0.43887776 -0.42685371 -0.41482966
#  -0.40280561 -0.39078156 -0.37875752 -0.36673347 -0.35470942 -0.34268537
#  -0.33066132 -0.31863727 -0.30661323 -0.29458918 -0.28256513 -0.27054108
#  -0.25851703 -0.24649299 -0.23446894 -0.22244489 -0.21042084 -0.19839679
#  -0.18637275 -0.1743487  -0.16232465 -0.1503006  -0.13827655 -0.12625251
#  -0.11422846 -0.10220441 -0.09018036 -0.07815631 -0.06613226 -0.05410822
#  -0.04208417 -0.03006012 -0.01803607 -0.00601202  0.00601202  0.01803607
#   0.03006012  0.04208417  0.05410822  0.06613226  0.07815631  0.09018036
#   0.10220441  0.11422846  0.12625251  0.13827655  0.1503006   0.16232465
#   0.1743487   0.18637275  0.19839679  0.21042084  0.22244489  0.23446894
#   0.24649299  0.25851703  0.27054108  0.28256513  0.29458918  0.30661323
#   0.31863727  0.33066132  0.34268537  0.35470942  0.36673347  0.37875752
#   0.39078156  0.40280561  0.41482966  0.42685371  0.43887776  0.4509018
#   0.46292585  0.4749499   0.48697395  0.498998    0.51102204  0.52304609
#   0.53507014  0.54709419  0.55911824  0.57114228  0.58316633  0.59519038
#   0.60721443  0.61923848  0.63126253  0.64328657  0.65531062  0.66733467
#   0.67935872  0.69138277  0.70340681  0.71543086  0.72745491  0.73947896
#   0.75150301  0.76352705  0.7755511   0.78757515  0.7995992   0.81162325
#   0.82364729  0.83567134  0.84769539  0.85971944  0.87174349  0.88376754
#   0.89579158  0.90781563  0.91983968  0.93186373  0.94388778  0.95591182
#   0.96793587  0.97995992  0.99198397  1.00400802  1.01603206  1.02805611
#   1.04008016  1.05210421  1.06412826  1.0761523   1.08817635  1.1002004
#   1.11222445  1.1242485   1.13627255  1.14829659  1.16032064  1.17234469
#   1.18436874  1.19639279  1.20841683  1.22044088  1.23246493  1.24448898
#   1.25651303  1.26853707  1.28056112  1.29258517  1.30460922  1.31663327
#   1.32865731  1.34068136  1.35270541  1.36472946  1.37675351  1.38877756
#   1.4008016   1.41282565  1.4248497   1.43687375  1.4488978   1.46092184
#   1.47294589  1.48496994  1.49699399  1.50901804  1.52104208  1.53306613
#   1.54509018  1.55711423  1.56913828  1.58116232  1.59318637  1.60521042
#   1.61723447  1.62925852  1.64128257  1.65330661  1.66533066  1.67735471
#   1.68937876  1.70140281  1.71342685  1.7254509   1.73747495  1.749499
#   1.76152305  1.77354709  1.78557114  1.79759519  1.80961924  1.82164329
#   1.83366733  1.84569138  1.85771543  1.86973948  1.88176353  1.89378758
#   1.90581162  1.91783567  1.92985972  1.94188377  1.95390782  1.96593186
#   1.97795591  1.98997996  2.00200401  2.01402806  2.0260521   2.03807615
#   2.0501002   2.06212425  2.0741483   2.08617234  2.09819639  2.11022044
#   2.12224449  2.13426854  2.14629259  2.15831663  2.17034068  2.18236473
#   2.19438878  2.20641283  2.21843687  2.23046092  2.24248497  2.25450902
#   2.26653307  2.27855711  2.29058116  2.30260521  2.31462926  2.32665331
#   2.33867735  2.3507014   2.36272545  2.3747495   2.38677355  2.3987976
#   2.41082164  2.42284569  2.43486974  2.44689379  2.45891784  2.47094188
#   2.48296593  2.49498998  2.50701403  2.51903808  2.53106212  2.54308617
#   2.55511022  2.56713427  2.57915832  2.59118236  2.60320641  2.61523046
#   2.62725451  2.63927856  2.65130261  2.66332665  2.6753507   2.68737475
#   2.6993988   2.71142285  2.72344689  2.73547094  2.74749499  2.75951904
#   2.77154309  2.78356713  2.79559118  2.80761523  2.81963928  2.83166333
#   2.84368737  2.85571142  2.86773547  2.87975952  2.89178357  2.90380762
#   2.91583166  2.92785571  2.93987976  2.95190381  2.96392786  2.9759519
#   2.98797595  3.        ]
# density #1, dimension = 1, sampler #0
# density #1, dimension = 1, sampler #1
# density #1, dimension = 1, sampler #2
# density #1, dimension = 1, sampler #3
# [-3.09232922  3.09232922]
# [-3.09232922 -3.07993511 -3.06754101 -3.0551469  -3.0427528  -3.03035869
#  -3.01796459 -3.00557048 -2.99317638 -2.98078227 -2.96838817 -2.95599406
#  -2.94359996 -2.93120585 -2.91881175 -2.90641764 -2.89402354 -2.88162943
#  -2.86923533 -2.85684122 -2.84444712 -2.83205301 -2.81965891 -2.8072648
#  -2.7948707  -2.78247659 -2.77008249 -2.75768838 -2.74529428 -2.73290017
#  -2.72050607 -2.70811196 -2.69571786 -2.68332375 -2.67092965 -2.65853554
#  -2.64614144 -2.63374733 -2.62135323 -2.60895912 -2.59656502 -2.58417091
#  -2.57177681 -2.5593827  -2.5469886  -2.53459449 -2.52220039 -2.50980628
#  -2.49741218 -2.48501807 -2.47262396 -2.46022986 -2.44783575 -2.43544165
#  -2.42304754 -2.41065344 -2.39825933 -2.38586523 -2.37347112 -2.36107702
#  -2.34868291 -2.33628881 -2.3238947  -2.3115006  -2.29910649 -2.28671239
#  -2.27431828 -2.26192418 -2.24953007 -2.23713597 -2.22474186 -2.21234776
#  -2.19995365 -2.18755955 -2.17516544 -2.16277134 -2.15037723 -2.13798313
#  -2.12558902 -2.11319492 -2.10080081 -2.08840671 -2.0760126  -2.0636185
#  -2.05122439 -2.03883029 -2.02643618 -2.01404208 -2.00164797 -1.98925387
#  -1.97685976 -1.96446566 -1.95207155 -1.93967745 -1.92728334 -1.91488924
#  -1.90249513 -1.89010103 -1.87770692 -1.86531282 -1.85291871 -1.84052461
#  -1.8281305  -1.8157364  -1.80334229 -1.79094819 -1.77855408 -1.76615997
#  -1.75376587 -1.74137176 -1.72897766 -1.71658355 -1.70418945 -1.69179534
#  -1.67940124 -1.66700713 -1.65461303 -1.64221892 -1.62982482 -1.61743071
#  -1.60503661 -1.5926425  -1.5802484  -1.56785429 -1.55546019 -1.54306608
#  -1.53067198 -1.51827787 -1.50588377 -1.49348966 -1.48109556 -1.46870145
#  -1.45630735 -1.44391324 -1.43151914 -1.41912503 -1.40673093 -1.39433682
#  -1.38194272 -1.36954861 -1.35715451 -1.3447604  -1.3323663  -1.31997219
#  -1.30757809 -1.29518398 -1.28278988 -1.27039577 -1.25800167 -1.24560756
#  -1.23321346 -1.22081935 -1.20842525 -1.19603114 -1.18363704 -1.17124293
#  -1.15884883 -1.14645472 -1.13406062 -1.12166651 -1.10927241 -1.0968783
#  -1.0844842  -1.07209009 -1.05969598 -1.04730188 -1.03490777 -1.02251367
#  -1.01011956 -0.99772546 -0.98533135 -0.97293725 -0.96054314 -0.94814904
#  -0.93575493 -0.92336083 -0.91096672 -0.89857262 -0.88617851 -0.87378441
#  -0.8613903  -0.8489962  -0.83660209 -0.82420799 -0.81181388 -0.79941978
#  -0.78702567 -0.77463157 -0.76223746 -0.74984336 -0.73744925 -0.72505515
#  -0.71266104 -0.70026694 -0.68787283 -0.67547873 -0.66308462 -0.65069052
#  -0.63829641 -0.62590231 -0.6135082  -0.6011141  -0.58871999 -0.57632589
#  -0.56393178 -0.55153768 -0.53914357 -0.52674947 -0.51435536 -0.50196126
#  -0.48956715 -0.47717305 -0.46477894 -0.45238484 -0.43999073 -0.42759663
#  -0.41520252 -0.40280842 -0.39041431 -0.37802021 -0.3656261  -0.35323199
#  -0.34083789 -0.32844378 -0.31604968 -0.30365557 -0.29126147 -0.27886736
#  -0.26647326 -0.25407915 -0.24168505 -0.22929094 -0.21689684 -0.20450273
#  -0.19210863 -0.17971452 -0.16732042 -0.15492631 -0.14253221 -0.1301381
#  -0.117744   -0.10534989 -0.09295579 -0.08056168 -0.06816758 -0.05577347
#  -0.04337937 -0.03098526 -0.01859116 -0.00619705  0.00619705  0.01859116
#   0.03098526  0.04337937  0.05577347  0.06816758  0.08056168  0.09295579
#   0.10534989  0.117744    0.1301381   0.14253221  0.15492631  0.16732042
#   0.17971452  0.19210863  0.20450273  0.21689684  0.22929094  0.24168505
#   0.25407915  0.26647326  0.27886736  0.29126147  0.30365557  0.31604968
#   0.32844378  0.34083789  0.35323199  0.3656261   0.37802021  0.39041431
#   0.40280842  0.41520252  0.42759663  0.43999073  0.45238484  0.46477894
#   0.47717305  0.48956715  0.50196126  0.51435536  0.52674947  0.53914357
#   0.55153768  0.56393178  0.57632589  0.58871999  0.6011141   0.6135082
#   0.62590231  0.63829641  0.65069052  0.66308462  0.67547873  0.68787283
#   0.70026694  0.71266104  0.72505515  0.73744925  0.74984336  0.76223746
#   0.77463157  0.78702567  0.79941978  0.81181388  0.82420799  0.83660209
#   0.8489962   0.8613903   0.87378441  0.88617851  0.89857262  0.91096672
#   0.92336083  0.93575493  0.94814904  0.96054314  0.97293725  0.98533135
#   0.99772546  1.01011956  1.02251367  1.03490777  1.04730188  1.05969598
#   1.07209009  1.0844842   1.0968783   1.10927241  1.12166651  1.13406062
#   1.14645472  1.15884883  1.17124293  1.18363704  1.19603114  1.20842525
#   1.22081935  1.23321346  1.24560756  1.25800167  1.27039577  1.28278988
#   1.29518398  1.30757809  1.31997219  1.3323663   1.3447604   1.35715451
#   1.36954861  1.38194272  1.39433682  1.40673093  1.41912503  1.43151914
#   1.44391324  1.45630735  1.46870145  1.48109556  1.49348966  1.50588377
#   1.51827787  1.53067198  1.54306608  1.55546019  1.56785429  1.5802484
#   1.5926425   1.60503661  1.61743071  1.62982482  1.64221892  1.65461303
#   1.66700713  1.67940124  1.69179534  1.70418945  1.71658355  1.72897766
#   1.74137176  1.75376587  1.76615997  1.77855408  1.79094819  1.80334229
#   1.8157364   1.8281305   1.84052461  1.85291871  1.86531282  1.87770692
#   1.89010103  1.90249513  1.91488924  1.92728334  1.93967745  1.95207155
#   1.96446566  1.97685976  1.98925387  2.00164797  2.01404208  2.02643618
#   2.03883029  2.05122439  2.0636185   2.0760126   2.08840671  2.10080081
#   2.11319492  2.12558902  2.13798313  2.15037723  2.16277134  2.17516544
#   2.18755955  2.19995365  2.21234776  2.22474186  2.23713597  2.24953007
#   2.26192418  2.27431828  2.28671239  2.29910649  2.3115006   2.3238947
#   2.33628881  2.34868291  2.36107702  2.37347112  2.38586523  2.39825933
#   2.41065344  2.42304754  2.43544165  2.44783575  2.46022986  2.47262396
#   2.48501807  2.49741218  2.50980628  2.52220039  2.53459449  2.5469886
#   2.5593827   2.57177681  2.58417091  2.59656502  2.60895912  2.62135323
#   2.63374733  2.64614144  2.65853554  2.67092965  2.68332375  2.69571786
#   2.70811196  2.72050607  2.73290017  2.74529428  2.75768838  2.77008249
#   2.78247659  2.7948707   2.8072648   2.81965891  2.83205301  2.84444712
#   2.85684122  2.86923533  2.88162943  2.89402354  2.90641764  2.91881175
#   2.93120585  2.94359996  2.95599406  2.96838817  2.98078227  2.99317638
#   3.00557048  3.01796459  3.03035869  3.0427528   3.0551469   3.06754101
#   3.07993511  3.09232922]
# density #1, dimension = 2, sampler #0
# density #1, dimension = 2, sampler #1
# density #1, dimension = 2, sampler #2
# density #1, dimension = 2, sampler #3
# [-3.11819938  3.11819938]
# [-3.11819938 -3.10570158 -3.09320379 -3.080706   -3.06820821 -3.05571041
#  -3.04321262 -3.03071483 -3.01821703 -3.00571924 -2.99322145 -2.98072365
#  -2.96822586 -2.95572807 -2.94323027 -2.93073248 -2.91823469 -2.9057369
#  -2.8932391  -2.88074131 -2.86824352 -2.85574572 -2.84324793 -2.83075014
#  -2.81825234 -2.80575455 -2.79325676 -2.78075896 -2.76826117 -2.75576338
#  -2.74326559 -2.73076779 -2.71827    -2.70577221 -2.69327441 -2.68077662
#  -2.66827883 -2.65578103 -2.64328324 -2.63078545 -2.61828765 -2.60578986
#  -2.59329207 -2.58079427 -2.56829648 -2.55579869 -2.5433009  -2.5308031
#  -2.51830531 -2.50580752 -2.49330972 -2.48081193 -2.46831414 -2.45581634
#  -2.44331855 -2.43082076 -2.41832296 -2.40582517 -2.39332738 -2.38082959
#  -2.36833179 -2.355834   -2.34333621 -2.33083841 -2.31834062 -2.30584283
#  -2.29334503 -2.28084724 -2.26834945 -2.25585165 -2.24335386 -2.23085607
#  -2.21835827 -2.20586048 -2.19336269 -2.1808649  -2.1683671  -2.15586931
#  -2.14337152 -2.13087372 -2.11837593 -2.10587814 -2.09338034 -2.08088255
#  -2.06838476 -2.05588696 -2.04338917 -2.03089138 -2.01839359 -2.00589579
#  -1.993398   -1.98090021 -1.96840241 -1.95590462 -1.94340683 -1.93090903
#  -1.91841124 -1.90591345 -1.89341565 -1.88091786 -1.86842007 -1.85592228
#  -1.84342448 -1.83092669 -1.8184289  -1.8059311  -1.79343331 -1.78093552
#  -1.76843772 -1.75593993 -1.74344214 -1.73094434 -1.71844655 -1.70594876
#  -1.69345096 -1.68095317 -1.66845538 -1.65595759 -1.64345979 -1.630962
#  -1.61846421 -1.60596641 -1.59346862 -1.58097083 -1.56847303 -1.55597524
#  -1.54347745 -1.53097965 -1.51848186 -1.50598407 -1.49348628 -1.48098848
#  -1.46849069 -1.4559929  -1.4434951  -1.43099731 -1.41849952 -1.40600172
#  -1.39350393 -1.38100614 -1.36850834 -1.35601055 -1.34351276 -1.33101496
#  -1.31851717 -1.30601938 -1.29352159 -1.28102379 -1.268526   -1.25602821
#  -1.24353041 -1.23103262 -1.21853483 -1.20603703 -1.19353924 -1.18104145
#  -1.16854365 -1.15604586 -1.14354807 -1.13105028 -1.11855248 -1.10605469
#  -1.0935569  -1.0810591  -1.06856131 -1.05606352 -1.04356572 -1.03106793
#  -1.01857014 -1.00607234 -0.99357455 -0.98107676 -0.96857897 -0.95608117
#  -0.94358338 -0.93108559 -0.91858779 -0.90609    -0.89359221 -0.88109441
#  -0.86859662 -0.85609883 -0.84360103 -0.83110324 -0.81860545 -0.80610765
#  -0.79360986 -0.78111207 -0.76861428 -0.75611648 -0.74361869 -0.7311209
#  -0.7186231  -0.70612531 -0.69362752 -0.68112972 -0.66863193 -0.65613414
#  -0.64363634 -0.63113855 -0.61864076 -0.60614297 -0.59364517 -0.58114738
#  -0.56864959 -0.55615179 -0.543654   -0.53115621 -0.51865841 -0.50616062
#  -0.49366283 -0.48116503 -0.46866724 -0.45616945 -0.44367165 -0.43117386
#  -0.41867607 -0.40617828 -0.39368048 -0.38118269 -0.3686849  -0.3561871
#  -0.34368931 -0.33119152 -0.31869372 -0.30619593 -0.29369814 -0.28120034
#  -0.26870255 -0.25620476 -0.24370697 -0.23120917 -0.21871138 -0.20621359
#  -0.19371579 -0.181218   -0.16872021 -0.15622241 -0.14372462 -0.13122683
#  -0.11872903 -0.10623124 -0.09373345 -0.08123566 -0.06873786 -0.05624007
#  -0.04374228 -0.03124448 -0.01874669 -0.0062489   0.0062489   0.01874669
#   0.03124448  0.04374228  0.05624007  0.06873786  0.08123566  0.09373345
#   0.10623124  0.11872903  0.13122683  0.14372462  0.15622241  0.16872021
#   0.181218    0.19371579  0.20621359  0.21871138  0.23120917  0.24370697
#   0.25620476  0.26870255  0.28120034  0.29369814  0.30619593  0.31869372
#   0.33119152  0.34368931  0.3561871   0.3686849   0.38118269  0.39368048
#   0.40617828  0.41867607  0.43117386  0.44367165  0.45616945  0.46866724
#   0.48116503  0.49366283  0.50616062  0.51865841  0.53115621  0.543654
#   0.55615179  0.56864959  0.58114738  0.59364517  0.60614297  0.61864076
#   0.63113855  0.64363634  0.65613414  0.66863193  0.68112972  0.69362752
#   0.70612531  0.7186231   0.7311209   0.74361869  0.75611648  0.76861428
#   0.78111207  0.79360986  0.80610765  0.81860545  0.83110324  0.84360103
#   0.85609883  0.86859662  0.88109441  0.89359221  0.90609     0.91858779
#   0.93108559  0.94358338  0.95608117  0.96857897  0.98107676  0.99357455
#   1.00607234  1.01857014  1.03106793  1.04356572  1.05606352  1.06856131
#   1.0810591   1.0935569   1.10605469  1.11855248  1.13105028  1.14354807
#   1.15604586  1.16854365  1.18104145  1.19353924  1.20603703  1.21853483
#   1.23103262  1.24353041  1.25602821  1.268526    1.28102379  1.29352159
#   1.30601938  1.31851717  1.33101496  1.34351276  1.35601055  1.36850834
#   1.38100614  1.39350393  1.40600172  1.41849952  1.43099731  1.4434951
#   1.4559929   1.46849069  1.48098848  1.49348628  1.50598407  1.51848186
#   1.53097965  1.54347745  1.55597524  1.56847303  1.58097083  1.59346862
#   1.60596641  1.61846421  1.630962    1.64345979  1.65595759  1.66845538
#   1.68095317  1.69345096  1.70594876  1.71844655  1.73094434  1.74344214
#   1.75593993  1.76843772  1.78093552  1.79343331  1.8059311   1.8184289
#   1.83092669  1.84342448  1.85592228  1.86842007  1.88091786  1.89341565
#   1.90591345  1.91841124  1.93090903  1.94340683  1.95590462  1.96840241
#   1.98090021  1.993398    2.00589579  2.01839359  2.03089138  2.04338917
#   2.05588696  2.06838476  2.08088255  2.09338034  2.10587814  2.11837593
#   2.13087372  2.14337152  2.15586931  2.1683671   2.1808649   2.19336269
#   2.20586048  2.21835827  2.23085607  2.24335386  2.25585165  2.26834945
#   2.28084724  2.29334503  2.30584283  2.31834062  2.33083841  2.34333621
#   2.355834    2.36833179  2.38082959  2.39332738  2.40582517  2.41832296
#   2.43082076  2.44331855  2.45581634  2.46831414  2.48081193  2.49330972
#   2.50580752  2.51830531  2.5308031   2.5433009   2.55579869  2.56829648
#   2.58079427  2.59329207  2.60578986  2.61828765  2.63078545  2.64328324
#   2.65578103  2.66827883  2.68077662  2.69327441  2.70577221  2.71827
#   2.73076779  2.74326559  2.75576338  2.76826117  2.78075896  2.79325676
#   2.80575455  2.81825234  2.83075014  2.84324793  2.85574572  2.86824352
#   2.88074131  2.8932391   2.9057369   2.91823469  2.93073248  2.94323027
#   2.95572807  2.96822586  2.98072365  2.99322145  3.00571924  3.01821703
#   3.03071483  3.04321262  3.05571041  3.06820821  3.080706    3.09320379
#   3.10570158  3.11819938]
# density #1, dimension = 5, sampler #0
# density #1, dimension = 5, sampler #1
# density #1, dimension = 5, sampler #2
# density #1, dimension = 5, sampler #3

# %% [markdown]
# # Stopping here for now

# %% [markdown]
# ### Hermite functions

# %% [markdown]
# #### Constructing a density kernel whose integral is one and whose integral against low order polynomials vanishes

# %% [markdown]
# Define a kernel in terms of Hermite polynomials so that integrates to one and integrates to zero for higher order polynomials

# %%
y = sy.symbols('y', real = True)
h = sy.symbols('h', positive = True)
def sy_hermite_kernel(y = sy.symbols('y', real = True), band_width = sy.symbols('h', positive = True), r = 1, only_coef = False):
    '''
    band_width = the kernel band width, often denoted h; a smaller bandwidth means a peakier kernel
    r = number of terms in our kernel
    '''
#    import sympy as sy
    wt = sy.exp(-y*y) #normalizing weight for Hermite functions
    k = sy.zeros(r,1) #initialize a vector of bases that make up the kernel
    intk = sy.zeros(r,r) #initialize a matrix of integrals of the bases with respect to even degree polynomials
    for ii in range(r):
        k[ii] = sy.hermite(2*ii,y)*wt #form the bases
        for jj in range(r):
            intk[jj,ii] = sy.integrate(k[ii]*(y**(2*jj)),(y,-sy.oo,sy.oo)) #evaluate the integrals against even degree monomials
    tot_int = sy.Matrix.vstack(sy.ones(1,1),sy.zeros(r-1,1)) #the kernel should integrate to one, 
        #and the kernel integrated against y, y^2, ..., y^r should be zero
#    print(tot_int)
    coef = sy.Matrix(list(sy.linsolve((intk,tot_int)))) #solve the system of equations for the coefficients of the bases
    if only_coef:
        return coef
    print(coef)
#    ktilde = coef.dot(k)
#    integk = sy.integrate(ktilde,(y,-sy.oo,sy.oo))
#    print('integk =',integk)
    ktilde = coef.dot(k.subs(y,y/band_width)/band_width) #form the isotropic kernel and insert the bandwidth dependency
#    integ = sy.integrate(ktilde,(y,-sy.oo,sy.oo))
#    print('integ =',integ)
#    print(band_width)
#    print(ktilde)
    return coef.dot(k.subs(y,y/band_width)/band_width)

# %%
test_kernel_sy = sy_hermite_kernel(r=1)
print(type(test_kernel_sy))
print('kernel =',test_kernel_sy)
integ = sy.integrate(test_kernel_sy,(y,-sy.oo,sy.oo))
print('integ =',integ)
test_kernel_sy = sy_hermite_kernel(r=2,only_coef = True)
print(test_kernel_sy)
# Out:
# Matrix([[1/sqrt(pi)]])
# <class 'sympy.core.mul.Mul'>
# kernel = exp(-y**2/h**2)/(sqrt(pi)*h)
# integ = 1
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi))]])

# %% [markdown]
# #### Look at this kernel for different values of the order and the bandwidth
# A smaller bandwidth makes a peakier kernel
#
# A higher order means that there is potentially higher accuracy, although it may mean that the KDE has negative values

# %%
h = sy.symbols('h', positive = True)
y = sy.symbols('y', real = True)
rarray = sy.Matrix([sy.Integer(1), sy.Integer(2), sy.Integer(3)])
nr = rarray.shape[0]

# %%
harray = sy.Matrix([sy.Rational(1/2), sy.Rational(1), sy.Rational(4)])
nh = harray.shape[0]
p = [];
for rr in range(nr):
    rval = rarray[rr]
    ktilde_sy = sy.simplify(sy_hermite_kernel(y,h,rval))
    print('ktilde =',sy.latex(ktilde_sy.subs(h,1)))
    for hh in range(nh):
        hval = harray[hh]
        p.append(sy.plot(ktilde_sy.subs(h,hval),ylabel = r'$\tilde k(y,r='+str(rval)+',h='+str(hval)+')$', show = False))
sy.plotting.PlotGrid(nr,nh, *p, size = (10,10));
# Out:
# Matrix([[1/sqrt(pi)]])
# ktilde = \frac{e^{- y^{2}}}{\sqrt{\pi}}
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi))]])
# ktilde = \frac{\left(\frac{3}{2} - y^{2}\right) e^{- y^{2}}}{\sqrt{\pi}}
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi)), 1/(32*sqrt(pi))]])
# ktilde = \frac{\left(4 y^{4} - 20 y^{2} + 15\right) e^{- y^{2}}}{8 \sqrt{\pi}}

# %% [markdown]
# #### Smoothing a density with respect to these kernels

# %%
r = 2
trial_density_sy = sy.stats.density(sy.stats.Normal(x,0,1))(y)
print(trial_density_sy)
ktilde_sy = sy_hermite_kernel(y,h,r)
integ = sy.integrate(ktilde_sy,(y,-sy.oo,sy.oo))
print(integ)
smoothed_density_sy = sy.integrate(trial_density_sy.subs(y,y-z)*ktilde_sy.subs(y,z),(z,-sy.oo,sy.oo))
print(smoothed_density_sy)
# Out:
# sqrt(2)*exp(-y**2/2)/(2*sqrt(pi))
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi))]])
# 1
# 3*(2 - erfc(y/(h*sqrt(h**2/2 + 1))))*sqrt(h**2 + 2)*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))/(8*sqrt(pi)*(h**2/2 + 1)) + 3*sqrt(h**2 + 2)*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))*erfc(y/(h*sqrt(h**2/2 + 1)))/(8*sqrt(pi)*(h**2/2 + 1)) - sqrt(2)*(-sqrt(pi)*h*sqrt(h**2/2 + 1)/(2*y) + sqrt(pi)*(-1/2 - y**2/(h**2*(h**2/2 + 1)))*(-2*h*sqrt(h**2/2 + 1)*exp(-y**2/(h**2*(h**2/2 + 1)))/y - 2*sqrt(pi)*(2 - erfc(y/(h*sqrt(h**2/2 + 1)))))*exp(y**2/(h**2*(h**2/2 + 1)))/2)*exp(-y**2/h**2)/(4*pi**(3/2)*(h**2/2 + 1)**(3/2)) - sqrt(2)*(sqrt(pi)*h*sqrt(h**2/2 + 1)/(2*y) + sqrt(pi)*(-1/2 - y**2/(h**2*(h**2/2 + 1)))*(2*h*sqrt(h**2/2 + 1)*exp(-y**2/(h**2*(h**2/2 + 1)))/y - 2*sqrt(pi)*erfc(y/(h*sqrt(h**2/2 + 1))))*exp(y**2/(h**2*(h**2/2 + 1)))/2)*exp(-y**2/h**2)/(4*pi**(3/2)*(h**2/2 + 1)**(3/2)) - y**2*(2 - erfc(y/(h*sqrt(h**2/2 + 1))))*sqrt(h**2 + 2)*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))/(4*sqrt(pi)*h**2*(h**2/2 + 1)) - y**2*sqrt(h**2 + 2)*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))*erfc(y/(h*sqrt(h**2/2 + 1)))/(4*sqrt(pi)*h**2*(h**2/2 + 1)) - sqrt(2)*y**2*(-2*h*sqrt(h**2/2 + 1)*exp(-y**2/(h**2*(h**2/2 + 1)))/y - 2*sqrt(pi)*(2 - erfc(y/(h*sqrt(h**2/2 + 1)))))*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))/(4*pi*h**2*(h**2/2 + 1)**(3/2)) - sqrt(2)*y**2*(2*h*sqrt(h**2/2 + 1)*exp(-y**2/(h**2*(h**2/2 + 1)))/y - 2*sqrt(pi)*erfc(y/(h*sqrt(h**2/2 + 1))))*exp(-y**2/h**2)*exp(y**2/(h**2*(h**2/2 + 1)))/(4*pi*h**2*(h**2/2 + 1)**(3/2))

# %%
harray = sy.Matrix([sy.Rational(1/10), sy.Rational(1/2), sy.Rational(1)])
nh = harray.shape[0]
p = []
plog = []
for rr in range(nr):
    rval = rarray[rr]
    ktilde_sy = sy_hermite_kernel(y,h,rval)
    smoothed_density_sy = sy.integrate(trial_density_sy.subs(y,y-z)*ktilde_sy.subs(y,z),(z,-sy.oo,sy.oo))
    for hh in range(nh):
        hval = harray[hh]
        p.append(sy.plot(trial_density_sy,smoothed_density_sy.subs(h,hval),ylabel = r'$r='+str(rval)+', h='+str(sy.N(hval,3))+'$', show = False))
        plog.append(sy.plot(trial_density_sy,smoothed_density_sy.subs(h,hval),ylabel = r'$r='+str(rval)+', h='+str(sy.N(hval,3))+'$', yscale = 'log', show = False))
sy.plotting.PlotGrid(nr,nh, *p, size = (10,10));
sy.plotting.PlotGrid(nr,nh, *plog, size = (10,10));
# Out:
# Matrix([[1/sqrt(pi)]])
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi))]])
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi)), 1/(32*sqrt(pi))]])

# %%
ktilde_sy = sy_hermite_kernel(y,h,1)
ktilde_n = sy.lambdify((y,h),ktilde_sy)
print('ktilde(0,1) =',ktilde_sy.subs([(y,0),(h,1)]),'=',sy.N(ktilde_sy.subs([(y,0),(h,1)])),'=',ktilde_n(0,1))
yval = np.linspace(-3,3,7)
print('yval =',yval)
print(yval.shape)
ktilde_n(yval.reshape(7,1)-yval,1)
# Out:
# Matrix([[1/sqrt(pi)]])
# ktilde(0,1) = 1/sqrt(pi) = 0.564189583547756 = 0.5641895835477563
# yval = [-3. -2. -1.  0.  1.  2.  3.]
# (7,)
# array([[5.64189584e-01, 2.07553749e-01, 1.03334927e-02, 6.96265260e-05,
#         6.34911734e-08, 7.83543327e-12, 1.30865062e-16],
#        [2.07553749e-01, 5.64189584e-01, 2.07553749e-01, 1.03334927e-02,
#         6.96265260e-05, 6.34911734e-08, 7.83543327e-12],
#        [1.03334927e-02, 2.07553749e-01, 5.64189584e-01, 2.07553749e-01,
#         1.03334927e-02, 6.96265260e-05, 6.34911734e-08],
#        [6.96265260e-05, 1.03334927e-02, 2.07553749e-01, 5.64189584e-01,
#         2.07553749e-01, 1.03334927e-02, 6.96265260e-05],
#        [6.34911734e-08, 6.96265260e-05, 1.03334927e-02, 2.07553749e-01,
#         5.64189584e-01, 2.07553749e-01, 1.03334927e-02],
#        [7.83543327e-12, 6.34911734e-08, 6.96265260e-05, 1.03334927e-02,
#         2.07553749e-01, 5.64189584e-01, 2.07553749e-01],
#        [1.30865062e-16, 7.83543327e-12, 6.34911734e-08, 6.96265260e-05,
#         1.03334927e-02, 2.07553749e-01, 5.64189584e-01]])

# %% [markdown]
# #### Computing the quality of merit of the density kernel

# %%
h = sy.symbols('h',positive = True)
ktilde = sy_hermite_kernel(y,h,2) #density kernel
hval = 1
sy.plot(ktilde.subs(h,hval),ylabel = r'$\tilde k(y,'+str(hval)+'1)$')
KYtilde = sy.exp(-y**2/2/(sy.sqrt(2*sy.pi))) #reproducing kernel
sy.plot(KYtilde,ylabel = r'$\tilde K^Y(y)$')
integone = sy.simplify(sy.integrate(ktilde.subs(h,1) * KYtilde.subs(y,(y-z)*h),(y,-sy.oo,sy.oo)))
print(integone)
sy.plot(integone.subs(h,1/10),ylabel = 'first integral(z)', xlim = [-100,100], ylim=[-10,1]);
print(sy.N(integone.subs([(h,1/10), (z,20)])))
#print(sy.N(integone))
#kqual = sy.simplify(KYtilde.subs(y,0) - 2*sy.integrate(ktilde * KYtilde.subs(y,y*h),(y,-sy.oo,sy.oo)) \
#    + sy.integrate(integone * ktilde.subs(y,z),(z,-sy.oo,sy.oo)))
#print(kqual)
# Out:
# Matrix([[1/sqrt(pi), -1/(4*sqrt(pi))]])
# pi**(1/4)*(-2*h**4*z**2 + 3*h**4 + 10*sqrt(2)*sqrt(pi)*h**2 + 16*pi)*exp(z**2*(-1 + 4*sqrt(pi)/(sqrt(2)*h**2 + 4*sqrt(pi))))/(sqrt(sqrt(2)*h**2 + 4*sqrt(pi))*(h**4 + 4*sqrt(2)*sqrt(pi)*h**2 + 8*pi))
# 0.450281397058513

# %%
print(sy.N(integone.subs([(h,1/10), (z,1000)])))
# Out:
# -8.00880907842049e-865

# %%
wt = sy.exp(-z*z/2)
#partial = sy.integrate((-sy.sqrt(2)*h**4*z**2 + 7*sy.sqrt(2)*h**4/4 + 5*sy.sqrt(sy.pi)*h**2 ) * wt,(z,-sy.oo,sy.oo))
partial = sy.integrate((sy.exp(z**2*(-1/2 + sy.sqrt(sy.pi)/(sy.sqrt(2)*h**2 + 2*sy.sqrt(sy.pi))))) * wt,(z,-sy.oo,sy.oo))
print(partial)
# Out:
# sqrt(2)*sqrt(pi)/sqrt(1 - 2*polar_lift(-0.5 + sqrt(pi)/(sqrt(2)*h**2 + 2*sqrt(pi))))

# %%
sy.plot(kqual, (h,0.01,10), xscale = 'log', yscale = 'log', ylabel = 'Smoothing Quality', axis_center = (0.008,1e-9));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sy.plot(kqual, (h,0.01,10), xscale = 'log', yscale = 'log', ylabel = 'Smoothing Quality', axis_center = (0.008,1e-9));
#
# NameError: name 'kqual' is not defined

# %% [markdown]
# ## Numeric Isotropic Kernels

# %% [markdown]
# ### Define Hermite kernels

# %%
def hermite_kernel(y, r = 1):
    '''
    r = number of terms in our kernel
    '''
    coef = np.array(sy.N(sy_hermite_kernel(r = r, only_coef = True)))
    print(coef)
    poly = sp.special.hermite(0)
    print(poly)
    k = sp.special.hermite(0)(y)*coef[0] #initialize a vector of kernel values
    print(k)
    for ii in range(1,r):
        k += sp.special.hermite(2*ii)(y)*coef[ii] #add the additional terms
    k*=np.exp(-y*y/2) #normalizing weight for Hermite functions #form the isotropic kernel and insert the bandwidth dependency
    return k

# %%
y = np.linspace(-1,2,5)
print('y =',y)
print(type(y))
k = hermite_kernel(y)
print('k =',k)
# Out:
# y = [-1.   -0.25  0.5   1.25  2.  ]
# <class 'numpy.ndarray'>
# [[0.564189583547756]]
#
# 1
# [0.564189583547756 0.564189583547756 0.564189583547756 0.564189583547756
#  0.564189583547756]
# k = [0.342198280312217 0.546831294919853 0.497895559951388 0.258304813712196
#  0.0763547570885822]

# %% [markdown]
# ## Experiment with KDE

# %% [markdown]
# ### Generate some $x$ points

# %%
d = 3
coord_wts = 2.**(-np.array(range(0,d)))
print(coord_wts)
n = 2**12
iidpts = qp.IIDStdUniform(d).gen_samples(n)
print("iid pts",iidpts)
wtiidpts = np.multiply(iidpts,coord_wts)
print(wtiidpts)
sobpts = qp.Sobol(d).gen_samples(n)
print("sobol pts",sobpts)
# Out:
# [1.   0.5  0.25]
# iid pts [[0.65114913 0.57858707 0.98350886]
#  [0.48557053 0.1235619  0.51953297]
#  [0.56613323 0.92359004 0.36788396]
#  ...
#  [0.62562997 0.19118199 0.87024112]
#  [0.51425423 0.86821595 0.78736345]
#  [0.87860973 0.25222022 0.81115308]]
# [[0.65114913 0.28929354 0.24587722]
#  [0.48557053 0.06178095 0.12988324]
#  [0.56613323 0.46179502 0.09197099]
#  ...
#  [0.62562997 0.095591   0.21756028]
#  [0.51425423 0.43410798 0.19684086]
#  [0.87860973 0.12611011 0.20278827]]
# sobol pts [[0.70381125 0.44157536 0.18482637]
#  [0.27999504 0.95027103 0.85252769]
#  [0.78139361 0.5836286  0.55578029]
#  ...
#  [0.42342239 0.5463968  0.55730638]
#  [0.88967518 0.92890838 0.85478957]
#  [0.06349139 0.43559381 0.1864774 ]]

# %% [markdown]
# ### Generate some $y=f(x)$ points

# %%
def testfun(x,coord_wts = 1):
    wtx = np.multiply(x,coord_wts)
    y = 10*np.exp(-wtx.sum(1))*np.sin(np.pi*wtx.sum(1))
    return y

# %%
yiid = testfun(iidpts)
ysob = testfun(sobpts)

# %%
fig,ax = plt.subplots(2)
ax[0].plot(iidpts, yiid, 'b.', markersize = 2)
ax[1].plot(sobpts, ysob, 'b.', markersize = 2);

# %% [markdown]
# ### Compute the scipy kernel density estimator

# %%
def scipy_kde(data,where_to_evaluate):
    density_estimate = stats.gaussian_kde(data.T)
    kdevalues = density_estimate(where_to_evaluate)
    return kdevalues, density_estimate    
    #return density_estimate

# %%
right = np.max(ysob)
left = np.min(ysob)
step = (right-left)/500
xvalues = np.arange(left,right,step)
small_n = int(np.sqrt(n))

# %%
kdeiidsmall, trash = kde(yiid[:small_n],xvalues)
print('small_n',small_n)
print('kdeiidsmall',kdeiidsmall[:10])
kdeiid, trash = kde(yiid,xvalues)
kdesobsmall, trash = kde(ysob[:small_n],xvalues)
kdesob, trash = kde(ysob,xvalues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 kdeiidsmall, trash = kde(yiid[:small_n],xvalues)
#       2 print('small_n',small_n)
#       3 print('kdeiidsmall',kdeiidsmall[:10])
#
# NameError: name 'kde' is not defined

# %%
fig,ax = plt.subplots(1,ncols=2,figsize = (10,4))
for ii in range(2):
#    ax[ii].plot(xvalues, stats.norm.pdf(xvalues), 'k-', linewidth = 2);
    ax[ii].plot(xvalues, kdeiid, 'b-', linewidth = 2)
    ax[ii].plot(xvalues, kdeiidsmall, 'g-', linewidth = 2)
    ax[ii].plot(xvalues, kdesob, 'c-', linewidth = 2)
    ax[ii].plot(xvalues, kdesobsmall, 'm-', linewidth = 2);
ax[1].set_yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 fig,ax = plt.subplots(1,ncols=2,figsize = (10,4))
#       2 for ii in range(2):
#       3 #    ax[ii].plot(xvalues, stats.norm.pdf(xvalues), 'k-', linewidth = 2);
# ----> 4     ax[ii].plot(xvalues, kdeiid, 'b-', linewidth = 2)
#       5     ax[ii].plot(xvalues, kdeiidsmall, 'g-', linewidth = 2)
#       6     ax[ii].plot(xvalues, kdesob, 'c-', linewidth = 2)
#
# NameError: name 'kdeiid' is not defined

# %% [markdown]
# ### Compute the vanilla kernel density estimator

# %%
def vanilla_kde(data,where_to_evaluate,kernel = hermite_kernel(),band_width = 1):
    density_estimate = lambda y : kernel((y - data.T)/band_width).mean(1)
    kdevalues = density_estimate(where_to_evaluate)
    return kdevalues, density_estimate    
    #return density_estimate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 def vanilla_kde(data,where_to_evaluate,kernel = hermite_kernel(),band_width = 1):
#       2     density_estimate = lambda y : kernel((y - data.T)/band_width).mean(1)
#       3     kdevalues = density_estimate(where_to_evaluate)
#
# TypeError: hermite_kernel() missing 1 required positional argument: 'y'

# %% [markdown]
# ## Decomposition

# %%
x1, x2 = sy.symbols('x1 x2')
f = x2*sy.cos(x1) - 3*x1
fnull = f.subs([(x1,sy.S(1)/2),(x2,sy.S(1)/2)])
f1 = f.subs(x2,sy.S(1)/2) - fnull
f2 = f.subs(x1,sy.S(1)/2) - fnull
f12 = f - f1 - f2 - fnull
print(f)
print(fnull)
print(f1)
print(f2)
print(f12)
# Out:
# -3*x1 + x2*cos(x1)
# -3/2 + cos(1/2)/2
# -3*x1 + cos(x1)/2 - cos(1/2)/2 + 3/2
# x2*cos(1/2) - cos(1/2)/2
# x2*cos(x1) - x2*cos(1/2) - cos(x1)/2 + cos(1/2)/2

# %%
# Out:
# 0.3333333333333333
