# %% [markdown]
# # Experiments for CIs assuming a bounded kurtosis using RQMC - Kurtosis Plots

# %% [markdown]
# Importing modules

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.stats import kurtosis, norm

# %% [markdown]
# Organizing data from the npz files

# %%
files = [f for f in os.listdir("./all_npz_files/") if ".npz" in f]
M = max(int(f.split(".")[3]) for f in files)
R = max(int(f.split(".")[7]) for f in files)
data_first = np.load("./all_npz_files/" + files[0])
data = {key: np.nan * np.ones((M, R, x.shape[-2], x.shape[-1])) for key, x in data_first.items()}
for f in files:
    M_start = int(f.split(".")[1])
    M_end   = int(f.split(".")[3])
    R_start = int(f.split(".")[5])
    R_end   = int(f.split(".")[7])
    data_chunk = np.load("./all_npz_files/" + f)
    assert data_chunk.keys() == data.keys()
    for key, x in data_chunk.items():
        data[key][M_start:M_end, R_start:R_end] = x
for key, x in data.items():
    assert not np.isnan(x).any()
    print("data['%s'].shape = %s" % (key, str(x.shape)))
# Out:
# data['d.1.p.2.mmax.3.n.8'].shape = (100, 1000, 8, 1)
# data['d.2.p.2.mmax.3.n.8'].shape = (100, 1000, 8, 2)
# data['d.4.p.5.mmax.3.n.125'].shape = (100, 1000, 125, 4)
# data['d.6.p.7.mmax.3.n.343'].shape = (100, 1000, 343, 6)

# %% [markdown]
# Getting the kurtosis values and appending the data to a csv

# %%
# ridge functions
def g_jmp(w): return w >= 1
def g_knk(w): return ((np.minimum(np.maximum(-2, w), 1)) + 2) / 3
def g_smo(w): return norm.cdf(w + 1)
def g_fin(w): return np.minimum(1, ((np.sqrt(np.maximum(w + 2, 0))) / 2))

gs = {"jmp": g_jmp, "knk": g_knk, "smo": g_smo, "fin": g_fin}

rows = []
for key, x in data.items():
    parts = key.split(".")
    d_val = int(parts[1])
    p_val = int(parts[3])
    mmax  = int(parts[5])
    n_max = int(parts[7])
    
    M_val, R_val, _, _ = x.shape
    
    x_norm = norm.ppf(x)  
    
    for m_idx in range(mmax + 1):
        n = p_val ** m_idx
        
        for m_repeat in range(M_val):

            w = x_norm[m_repeat, :, :n, :].sum(axis=2) / np.sqrt(d_val)  
            
            for g_name, g in gs.items():
                y = g(w).mean(axis=1)  
                kurt_val = kurtosis(y, bias=False, fisher=False)
                rows.append([g_name, d_val, m_idx, m_repeat, kurt_val])

df_long = pd.DataFrame(rows, columns=['Ridge Function', 'Dimension', 'm', 'm_repeat', 'Kurtosis'])

df_wide = df_long.pivot_table(
    index=['Ridge Function', 'Dimension', 'm'],
    columns='m_repeat',
    values='Kurtosis',
    sort=False
).reset_index()

df_wide.columns = ['Ridge Function', 'Dimension', 'm'] + [f'M{i+1}' for i in range(len(df_wide.columns)-3)]

gs_order = ["jmp", "knk", "smo", "fin"]
d_order = sorted(set(int(k.split(".")[1]) for k in data.keys()))

df_wide['Ridge Function'] = pd.Categorical(df_wide['Ridge Function'], categories=gs_order, ordered=True)
df_wide['Dimension'] = pd.Categorical(df_wide['Dimension'].astype(int), categories=d_order, ordered=True)
df_wide = df_wide.sort_values(['Ridge Function', 'Dimension', 'm']).reset_index(drop=True)

df_wide.to_csv('qmc_kurtosis_test.csv', index=False)
print("Saved to qmc_kurtosis_test.csv")
# Out:
# Saved to qmc_kurtosis_test.csv

# %% [markdown]
# Plotting the sample kurtosis (averaged across the M independent experiments/trials)

# %%
df = pd.read_csv('qmc_kurtosis_test.csv')
df['Dimension'] = df['Dimension'].astype(int)
df['m'] = df['m'].astype(int)

M_columns = [col for col in df.columns if col.startswith('M')]
df['M_mean'] = df[M_columns].mean(axis=1)

gs_names = df['Ridge Function'].unique().tolist()
d = df['Dimension'].unique()
m = df['m'].nunique()  # read m from CSV instead of relying on notebook variable

qmc_arr_averaged = np.empty((len(gs_names), len(d), m))

for i, ridge in enumerate(gs_names):
    for j, dim in enumerate(d):
        for k in range(m):
            mask = (df['Ridge Function'] == ridge) & (df['Dimension'] == int(dim)) & (df['m'] == k)
            qmc_arr_averaged[i, j, k] = df.loc[mask, 'M_mean'].values[0]

fig, axes = plt.subplots(len(d), len(gs_names), figsize=(7*len(gs_names), 5*len(d)))

x_vals = np.arange(m)
for dim_plot in range(len(d)):  
    for gs_plot in range(len(gs_names)):  
        ax = axes[dim_plot, gs_plot]
        ax.plot(x_vals, qmc_arr_averaged[gs_plot, dim_plot, :], marker='o')
        ax.set_xlabel('m', fontsize=10)
        ax.set_ylabel('Sample RQMC Kurtosis', fontsize=10)
        ax.set_title(f'{gs_names[gs_plot]}, d={d[dim_plot]}', fontsize=11, fontweight='bold')
        ax.set_xticks(x_vals)
        ax.grid(True, alpha=0.3, which='both')

plt.tight_layout()
plt.show()
