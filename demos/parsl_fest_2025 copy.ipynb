# %% [markdown]
# # [ParslFest 2025](https://parsl-project.org/parslfest/parslfest2025.html)
#
# # [Accelerating QMCpy Notebook Tests with Parsl](https://www.figma.com/slides/k7EUosssNluMihkYTLuh1F/Parsl-Testbook-Speedup?node-id=1-37&t=WnKcu2QYO8JXvtpP-0)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QMCSoftware/QMCSoftware/blob/develop/demos/parsl_fest_2025.ipynb)
#
# Joshua Herman and Sou-Cheng Choi, QMCPy Developers
#
# Aug 28 -- 29, 2025
#
# Updated: Sep 9, 2025

# %% [markdown]
# **Requirements**:
#
# * QMCPy: `pip install qmcpy==2.1`
# * LaTeX: `sudo apt update && sudo apt install -y texlive-full`
# * testbook : `pip install testbook==0.4.2`
# * Parsl: `pip install parsl==2025.7.28`
#
# This notebook can be run interactively or in command line mode. To run in command line mode, use:
# ```bash
#     conda activate qmcpy && cd demos && jupyter execute --kernel_name qmcpy parsl_fest_2025.ipynb
# ```
#
# Our presentation slides for ParslFest are available at [Figma](https://www.figma.com/slides/k7EUosssNluMihkYTLuh1F/Parsl-Testbook-Speedup?node-id=174-95&t=t3jENVMltXWwdLdb-0).

# %%
try:
    import qmcpy as qp
except ModuleNotFoundError:
    # !pip install -q qmcpy

try:
    import testbook as tb
except ModuleNotFoundError:
    # !pip install -q testbook

# %%
import sys
import os
import time
import inspect
import parsl as pl
from parsl.configs.htex_local import config

# %% [markdown]
# ## 1. Sequential Execution

# %%
start_time = time.time()
!(cd .. && make booktests_no_docker)
sequential_time = time.time() - start_time
# Out:
# find demos -name '*.ipynb' | while read nb; do \
# 	base=$(basename "$nb" .ipynb); \
# 	test_base=$(echo "$base" | sed 's/[-.]/_/g'); \
# 	if [ "$base" != "parsl_fest_2025" ] && ! ls test/booktests/tb_"$test_base".py > /dev/null 2>&1; then \
# 		echo "    Missing test for: $nb -> Expected: test/booktests/tb_$test_base.py"; \
# 	fi; \
# done
# Total notebooks:  33
# Total test files: 32
#
# Generating missing booktest files...
# cd test/booktests/ && python generate_test.py --check-missing
# No missing test files found.
# chmod +x scripts/find_local_only_folders.sh
# for f in .pdm-build/.gitignore .pdm-build/qmcpy.pth __pycache__/pdm_build.cpython-312.pyc build/lib.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/_c_lib.cpython-312-x86_64-linux-gnu.so build/temp.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/halton_qrng.o build/temp.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/util.o qmcpy/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/abstract_discrete_distribution.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/halton.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/iid_std_uniform.cpython-312.pyc qmcpy/discrete_distribution/_c_lib/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/_c_lib/_c_lib.cpython-312-x86_64-linux-gnu.so qmcpy/discrete_distribution/digital_net_b2/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/digital_net_b2/__pycache__/digital_net_b2.cpython-312.pyc qmcpy/discrete_distribution/lattice/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/lattice/__pycache__/lattice.cpython-312.pyc qmcpy/fast_transform/__pycache__/__init__.cpython-312.pyc qmcpy/fast_transform/__pycache__/ft.cpython-312.pyc qmcpy/fast_transform/__pycache__/ft_pytorch.cpython-312.pyc qmcpy/integrand/__pycache__/__init__.cpython-312.pyc qmcpy/integrand/__pycache__/abstract_integrand.cpython-312.pyc qmcpy/integrand/__pycache__/bayesian_lr_coeffs.cpython-312.pyc qmcpy/integrand/__pycache__/box_integral.cpython-312.pyc qmcpy/integrand/__pycache__/custom_fun.cpython-312.pyc qmcpy/integrand/__pycache__/financial_option.cpython-312.pyc qmcpy/integrand/__pycache__/fourbranch2d.cpython-312.pyc qmcpy/integrand/__pycache__/genz.cpython-312.pyc qmcpy/integrand/__pycache__/hartmann6d.cpython-312.pyc qmcpy/integrand/__pycache__/ishigami.cpython-312.pyc qmcpy/integrand/__pycache__/keister.cpython-312.pyc qmcpy/integrand/__pycache__/linear0.cpython-312.pyc qmcpy/integrand/__pycache__/multimodal2d.cpython-312.pyc qmcpy/integrand/__pycache__/sensitivity_indices.cpython-312.pyc qmcpy/integrand/__pycache__/sin1d.cpython-312.pyc qmcpy/integrand/__pycache__/umbridge_wrapper.cpython-312.pyc qmcpy/kernel/__pycache__/__init__.cpython-312.pyc qmcpy/kernel/__pycache__/abstract_kernel.cpython-312.pyc qmcpy/kernel/__pycache__/common_kernels.cpython-312.pyc qmcpy/kernel/__pycache__/multitask_kernel.cpython-312.pyc qmcpy/kernel/__pycache__/si_dsi_kernels.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/__init__.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_bayes_ld_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_mlmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_mlqmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_qmc_ld_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_stopping_criterion.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_clt.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_clt_vec.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlmc_cont.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlqmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlqmc_cont.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_bayes_lattice_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_bayes_net_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_lattice_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_net_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_rep_student_t.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/pf_gp_ci.cpython-312.pyc qmcpy/true_measure/__pycache__/__init__.cpython-312.pyc qmcpy/true_measure/__pycache__/abstract_true_measure.cpython-312.pyc qmcpy/true_measure/__pycache__/bernoulli_cont.cpython-312.py ...
# 	rm -f "$f"; \
# done
#
# Notebook tests
# pip install -q -e ".[test]"  && \
# set -e && \
# cd test/booktests/ && \
# rm -fr *.eps *.jpg *.pdf *.png *.part *.txt *.log prob_failure_gp_ci_plots && \
# PYTHONWARNINGS="ignore::UserWarning,ignore::DeprecationWarning,ignore::FutureWarning,ignore::ImportWarning" \
# python -W ignore -m coverage run --append --source=../../qmcpy/ -m unittest discover -s . -p "*.py" -v --failfast && \
# cd ../..
# test_argonne_talk_2023_figures_notebook (tb_Argonne_2023_Talk_Figures.NotebookTests.test_argonne_talk_2023_figures_notebook) ...
# 	Copied ../../demos/talk_paper_demos/Argonne_Talk_2023_May/iid_ld.pkl to iid_ld.pkl
#
# 	Copied ../../demos/talk_paper_demos/Argonne_Talk_2023_May/ld_parallel.pkl to ld_parallel.pkl
#     Memory used: 0.12 GB.  Test time: 392.24 s
# ok
# test_mcqmc2022_article_figures_notebook (tb_MCQMC2022_Article_Figures.NotebookTests.test_mcqmc2022_article_figures_notebook) ...
# 	Copied ../../demos/talk_paper_demos/MCQMC2022_Article_Figures/iid_ld.pkl to iid_ld.pkl
#
# 	Copied ../../demos/talk_paper_demos/MCQMC2022_Article_Figures/ld_parallel.pkl to ld_parallel.pkl
#     Memory used: 0.12 GB.  Test time: 16.17 s
# ok
# test_mcqmc_2020_qmc_software_tutorial_notebook (tb_MCQMC_2020_QMC_Software_Tutorial.NotebookTests.test_mcqmc_2020_qmc_software_tutorial_notebook) ...     Memory used: 0.12 GB.  Test time: 37.70 s
# ok
# test_purdue_talk_figures_notebook (tb_Purdue_Talk_Figures.NotebookTests.test_purdue_talk_figures_notebook) ...
# 	Copied ../../demos/talk_paper_demos/Purdue_Talk_2023_March/iid_ld.pkl to iid_ld.pkl
#
# 	Copied ../../demos/talk_paper_demos/Purdue_Talk_2023_March/ld_parallel.pkl to ld_parallel.pkl
#     Memory used: 0.12 GB.  Test time: 19.81 s
# ok
# test_acm_toms_sorokin_2025_notebook (tb_acm_toms_sorokin_2025.NotebookTests.test_acm_toms_sorokin_2025_notebook) ...     Memory used: 0.13 GB.  Test time: 1654.97 s
# ok
# test_asian_option_mlqmc_notebook (tb_asian_option_mlqmc.NotebookTests.test_asian_option_mlqmc_notebook) ...     Memory used: 0.13 GB.  Test time: 80.42 s
# ok
# test_control_variates_notebook (tb_control_variates.NotebookTests.test_control_variates_notebook) ...     Memory used: 0.13 GB.  Test time: 10.52 s
# ok
# test_dakota_genz_notebook (tb_dakota_genz.NotebookTests.test_dakota_genz_notebook) ...     Memory used: 0.13 GB.  Test time: 97.57 s
# ok
# test_digital_net_b2_notebook (tb_digital_net_b2.NotebookTests.test_digital_net_b2_notebook) ...     Memory used: 0.13 GB.  Test time: 40.24 s
# ok
# test_elliptic_pde_notebook (tb_elliptic_pde.NotebookTests.test_elliptic_pde_notebook) ...     Memory used: 0.13 GB.  Test time: 59.52 s
# ok
# test_gaussian_diagnostics_demo_notebook (tb_gaussian_diagnostics_demo.NotebookTests.test_gaussian_diagnostics_demo_notebook) ...     Memory used: 0.13 GB.  Test time: 33.34 s
# ok
# test_gbm_demo_notebook (tb_gbm_demo.NotebookTests.test_gbm_demo_notebook) ...     Memory used: 0.13 GB.  Test time: 3609.58 s
# ok
# test_iris_notebook (tb_iris.NotebookTests.test_iris_notebook) ...     Memory used: 0.13 GB.  Test time: 141.61 s
# ok
# test_joss2025_notebook (tb_joss2025.NotebookTests.test_joss2025_notebook) ...     Memory used: 0.13 GB.  Test time: 373.03 s
# ok
# test_lattice_random_generator_notebook (tb_lattice_random_generator.NotebookTests.test_lattice_random_generator_notebook) ...     Memory used: 0.13 GB.  Test time: 17.92 s
# ok
# test_lebesgue_integration_notebook (tb_lebesgue_integration.NotebookTests.test_lebesgue_integration_notebook) ...     Memory used: 0.13 GB.  Test time: 3.51 s
# ok
# test_linear_scrambled_halton_notebook (tb_linear_scrambled_halton.NotebookTests.test_linear_scrambled_halton_notebook) ...     Memory used: 0.13 GB.  Test time: 16.75 s
# ok
# test_nei_demo_notebook (tb_nei_demo.NotebookTests.test_nei_demo_notebook) ...     Memory used: 0.13 GB.  Test time: 7.27 s
# ok
# test_plot_proj_function_notebook (tb_plot_proj_function.NotebookTests.test_plot_proj_function_notebook) ...     Memory used: 0.13 GB.  Test time: 16.18 s
# ok
# test_pricing_options_notebook (tb_pricing_options.NotebookTests.test_pricing_options_notebook) ...     Memory used: 0.13 GB.  Test time: 10.16 s
# ok
# test_prob_failure_gp_ci_notebook (tb_prob_failure_gp_ci.NotebookTests.test_prob_failure_gp_ci_notebook) ... Skipping cell 18: import umbridge...
# Stopping execution at cell 18 (docker dependency)
#     Memory used: 0.13 GB.  Test time: 219.19 s
# ok
# test_pydata_chi_2023_notebook (tb_pydata_chi_2023.NotebookTests.test_pydata_chi_2023_notebook) ...     Memory used: 0.13 GB.  Test time: 16.99 s
# ok
# test_qei_demo_for_blog_notebook (tb_qei_demo_for_blog.NotebookTests.test_qei_demo_for_blog_notebook) ...     Memory used: 0.13 GB.  Test time: 86.74 s
# ok
# test_qmcpy_intro_notebook (tb_qmcpy_intro.NotebookTests.test_qmcpy_intro_notebook) ...     Memory used: 0.13 GB.  Test time: 3.48 s
# ok
# test_quickstart_notebook (tb_quickstart.NotebookTests.test_quickstart_notebook) ...     Memory used: 0.13 GB.  Test time: 3.66 s
# ok
# test_ray_tracing_notebook (tb_ray_tracing.NotebookTests.test_ray_tracing_notebook) ...     Memory used: 0.13 GB.  Test time: 37.50 s
# ok
# test_sample_scatter_plots_notebook (tb_sample_scatter_plots.NotebookTests.test_sample_scatter_plots_notebook) ...     Memory used: 0.13 GB.  Test time: 7.27 s
# ok
# test_some_true_measures_notebook (tb_some_true_measures.NotebookTests.test_some_true_measures_notebook) ...     Memory used: 0.13 GB.  Test time: 6.61 s
# ok
# test_umbridge_notebook (tb_umbridge.NotebookTests.test_umbridge_notebook) ... skipped 'Requires umbridge and docker'
# test_vectorized_qmc_notebook (tb_vectorized_qmc.NotebookTests.test_vectorized_qmc_notebook) ...     Memory used: 0.13 GB.  Test time: 17.61 s
# ok
# test_vectorized_qmc_bayes_notebook (tb_vectorized_qmc_bayes.NotebookTests.test_vectorized_qmc_bayes_notebook) ...     Memory used: 0.13 GB.  Test time: 70.13 s
# ok
# test_why_add_q_to_mc_blog_notebook (tb_why_add_q_to_mc_blog.NotebookTests.test_why_add_q_to_mc_blog_notebook) ...     Memory used: 0.13 GB.  Test time: 4.32 s
# ok
#
# ----------------------------------------------------------------------
# Ran 32 tests in 7113.007s
#
# OK (skipped=1)

# %% [markdown]
# ## 2. Parsl
#
# 1. Install and Configure Parsl
# 2. Run the tests in parallel with Parsl

# %% [markdown]
# ### 2.1 Install and Configure Parsl

# %%
try:
    import parsl as pl
except ModuleNotFoundError:
    # !pip install -q parsl
    
config.max_workers = 8  
if not pl.config:
    pl.load(config)
    print("Parsl loaded with memory limits")
else:
    print("Parsl already configured")
# Out:
# Parsl already configured

# %% [markdown]
# ### 2.2 Create a Parsl Test Runner

# %%
# Ensure the path to the booktests directory is included
sys.path.append(os.path.join(os.getcwd(), '..', 'test', 'booktests'))

# %%
import parsl_test_runner
import inspect

# See only functions
print("Functions:")
functions = inspect.getmembers(parsl_test_runner, inspect.isfunction)
for name, func in functions:
    print(f"- {name}")
print("\n" + "="*50)

# Get help on specific function
print("Help for execute_parallel_tests:")
help(parsl_test_runner.execute_parallel_tests)
# Out:
# Functions:
# - bash_app
# - execute_parallel_tests
# - generate_summary_report
# - main
#
# ==================================================
# Help for execute_parallel_tests:
# Help on function execute_parallel_tests in module parsl_test_runner:
#
# execute_parallel_tests()
#     Execute all testbook tests in parallel using Parsl

# %% [markdown]
# ### 2.3 Run the Notebooks in Parallel with Parsl

# %%
start_time2 = time.time()
!(cd .. && make booktests_parallel_no_docker)
parallel_time = time.time() - start_time2
# Out:
# find demos -name '*.ipynb' | while read nb; do \
# 	base=$(basename "$nb" .ipynb); \
# 	test_base=$(echo "$base" | sed 's/[-.]/_/g'); \
# 	if [ "$base" != "parsl_fest_2025" ] && ! ls test/booktests/tb_"$test_base".py > /dev/null 2>&1; then \
# 		echo "    Missing test for: $nb -> Expected: test/booktests/tb_$test_base.py"; \
# 	fi; \
# done
# Total notebooks:  33
# Total test files: 32
#
# Generating missing booktest files...
# cd test/booktests/ && python generate_test.py --check-missing
# No missing test files found.
# chmod +x scripts/find_local_only_folders.sh
# for f in .pdm-build/.gitignore .pdm-build/qmcpy.pth __pycache__/pdm_build.cpython-312.pyc build/lib.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/_c_lib.cpython-312-x86_64-linux-gnu.so build/temp.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/halton_qrng.o build/temp.linux-x86_64-cpython-312/qmcpy/discrete_distribution/_c_lib/util.o qmcpy/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/abstract_discrete_distribution.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/halton.cpython-312.pyc qmcpy/discrete_distribution/__pycache__/iid_std_uniform.cpython-312.pyc qmcpy/discrete_distribution/_c_lib/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/_c_lib/_c_lib.cpython-312-x86_64-linux-gnu.so qmcpy/discrete_distribution/digital_net_b2/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/digital_net_b2/__pycache__/digital_net_b2.cpython-312.pyc qmcpy/discrete_distribution/lattice/__pycache__/__init__.cpython-312.pyc qmcpy/discrete_distribution/lattice/__pycache__/lattice.cpython-312.pyc qmcpy/fast_transform/__pycache__/__init__.cpython-312.pyc qmcpy/fast_transform/__pycache__/ft.cpython-312.pyc qmcpy/fast_transform/__pycache__/ft_pytorch.cpython-312.pyc qmcpy/integrand/__pycache__/__init__.cpython-312.pyc qmcpy/integrand/__pycache__/abstract_integrand.cpython-312.pyc qmcpy/integrand/__pycache__/bayesian_lr_coeffs.cpython-312.pyc qmcpy/integrand/__pycache__/box_integral.cpython-312.pyc qmcpy/integrand/__pycache__/custom_fun.cpython-312.pyc qmcpy/integrand/__pycache__/financial_option.cpython-312.pyc qmcpy/integrand/__pycache__/fourbranch2d.cpython-312.pyc qmcpy/integrand/__pycache__/genz.cpython-312.pyc qmcpy/integrand/__pycache__/hartmann6d.cpython-312.pyc qmcpy/integrand/__pycache__/ishigami.cpython-312.pyc qmcpy/integrand/__pycache__/keister.cpython-312.pyc qmcpy/integrand/__pycache__/linear0.cpython-312.pyc qmcpy/integrand/__pycache__/multimodal2d.cpython-312.pyc qmcpy/integrand/__pycache__/sensitivity_indices.cpython-312.pyc qmcpy/integrand/__pycache__/sin1d.cpython-312.pyc qmcpy/integrand/__pycache__/umbridge_wrapper.cpython-312.pyc qmcpy/kernel/__pycache__/__init__.cpython-312.pyc qmcpy/kernel/__pycache__/abstract_kernel.cpython-312.pyc qmcpy/kernel/__pycache__/common_kernels.cpython-312.pyc qmcpy/kernel/__pycache__/multitask_kernel.cpython-312.pyc qmcpy/kernel/__pycache__/si_dsi_kernels.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/__init__.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_bayes_ld_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_mlmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_mlqmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_cub_qmc_ld_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/abstract_stopping_criterion.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_clt.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_clt_vec.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mc_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlmc_cont.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlqmc.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_mlqmc_cont.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_bayes_lattice_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_bayes_net_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_lattice_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_net_g.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/cub_qmc_rep_student_t.cpython-312.pyc qmcpy/stopping_criterion/__pycache__/pf_gp_ci.cpython-312.pyc qmcpy/true_measure/__pycache__/__init__.cpython-312.pyc qmcpy/true_measure/__pycache__/abstract_true_measure.cpython-312.pyc qmcpy/true_measure/__pycache__/bernoulli_cont.cpython-312.py ...
# 	rm -f "$f"; \
# done
#
# Notebook tests with Parsl
# pip install -q -e ".[test]"  && \
# cd test/booktests/ && \
# rm -fr *.eps *.jpg *.pdf *.png *.part *.txt *.log && rm -fr logs && rm -fr runinfo prob_failure_gp_ci_plots && \
# PYTHONWARNINGS="ignore::UserWarning,ignore::DeprecationWarning,ignore::FutureWarning,ignore::ImportWarning" \
# python parsl_test_runner.py -v --failfast && \
# cd ../..
# Parsl configuration loaded successfully.
# Found 32 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/32] tb_joss2025: PASSED
# [2/32] tb_qmcpy_intro: PASSED
# [3/32] tb_Argonne_2023_Talk_Figures: FAILED
# [4/32] tb_MCQMC2022_Article_Figures: PASSED
# [5/32] tb_gbm_demo: PASSED
# [6/32] tb_acm_toms_sorokin_2025: PASSED
# [7/32] tb_asian_option_mlqmc: PASSED
# [8/32] tb_prob_failure_gp_ci: PASSED
# [9/32] tb_why_add_q_to_mc_blog: PASSED
# [10/32] tb_some_true_measures: PASSED
# [11/32] tb_dakota_genz: PASSED
# [12/32] tb_lebesgue_integration: PASSED
# [13/32] tb_plot_proj_function: PASSED
# [14/32] tb_gaussian_diagnostics_demo: PASSED
# [15/32] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
# [16/32] tb_pricing_options: PASSED
# [17/32] tb_Purdue_Talk_Figures: FAILED
# [18/32] tb_nei_demo: PASSED
# [19/32] tb_iris: PASSED
# [20/32] tb_digital_net_b2: PASSED
# [21/32] tb_control_variates: PASSED
# [22/32] tb_vectorized_qmc_bayes: PASSED
# [23/32] tb_qei_demo_for_blog: PASSED
# [24/32] tb_lattice_random_generator: PASSED
# [25/32] tb_quickstart: PASSED
# [26/32] tb_elliptic_pde: PASSED
# [27/32] tb_sample_scatter_plots: PASSED
# [28/32] tb_pydata_chi_2023: PASSED
# [29/32] tb_linear_scrambled_halton: PASSED
# [30/32] tb_umbridge: PASSED
# [31/32] tb_ray_tracing: PASSED
# [32/32] tb_vectorized_qmc: PASSED
# ..F.............F...............
# ----------------------------------------------------------------------
# Ran 32 test modules in 1617.250s
#
# FAILED (failures=2)
#
# FAILURES:
# ======================================================================
# FAIL: tb_Argonne_2023_Talk_Figures
# ----------------------------------------------------------------------
# Error: FAILED: bash_app run_single_test failed with unix exit code 1
#
# FAIL: tb_Purdue_Talk_Figures
# ----------------------------------------------------------------------
# Error: FAILED: bash_app run_single_test failed with unix exit code 1

# %%
speedup = sequential_time / parallel_time
print(f"Sequential time:  {sequential_time:.2f} seconds")
print(f"Parallel time:    {parallel_time:.2f} seconds")
print(f"Speedup by Parsl: {speedup:.2f}")
# Out:
# Sequential time:  7133.85 seconds
# Parallel time:    1621.82 seconds
# Speedup by Parsl: 4.40

# %%
import platform

if platform.system().lower() == 'linux':
    # !uname -a
    # !nproc --all
    # !awk '/MemTotal/ {printf "%.2f GB\n", $2/1024/1024}' /proc/meminfo
# Out:
# Linux codespaces-2c03bb 6.8.0-1030-azure #35~22.04.1-Ubuntu SMP Mon May 26 18:08:30 UTC 2025 x86_64 x86_64 x86_64 GNU/Linux
# 16
# 62.80 GB
