# %% [markdown]
# # [ParslFest 2025](https://parsl-project.org/parslfest/parslfest2025.html)
#
# # [Accelerating QMCpy Notebook Tests with Parsl](https://www.figma.com/slides/k7EUosssNluMihkYTLuh1F/Parsl-Testbook-Speedup?node-id=1-37&t=WnKcu2QYO8JXvtpP-0)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QMCSoftware/QMCSoftware/blob/develop/demos/talk_paper_demos/parsel_fest_2025/parsl_fest_2025.ipynb)
#
# Joshua Herman, Brandon Sharp, and Sou-Cheng Choi, QMCPy Developers
#
# Aug 28 -- 29, 2025
#
# Updated: Dec 1, 2025
#
#
# **Requirements**:
#
# * testbook : `pip install testbook==0.4.2`
# * Parsl: `pip install parsl==2025.7.28`

# %%
try:
    import parsl as pl
except ModuleNotFoundError:
    # !pip install -q parsl

# %% [markdown]
# ## 2. Parsl
#
# 1. Install and setup Parcel
# 2. Run the tests in parallel with Parsl

# %% [markdown]
# ### 2.1 Parsl Setup and Baseline

# %%
import sys
import os
import time

import parsl as pl
from parsl.configs.htex_local import config
import importlib

# ----------------------------------------------------------------------
# Find repo root (directory containing pyproject.toml)
# ----------------------------------------------------------------------
def _find_repo_root(start=None):
    if start is None:
        start = os.getcwd()
    cur = start
    while True:
        if os.path.exists(os.path.join(cur, "pyproject.toml")):
            return cur
        parent = os.path.dirname(cur)
        if parent == cur:
            raise FileNotFoundError("repo root not found")
        cur = parent

repo_root = _find_repo_root()

# ----------------------------------------------------------------------
# Output directory (this notebook's output/)
# ----------------------------------------------------------------------
output_dir = "output"  # relative to parsel_fest_2025 notebook folder
os.makedirs(output_dir, exist_ok=True)

# Read sequential baseline time (from 01_sequential.ipynb)
seq_fname = os.path.join(output_dir, "sequential_time.csv")
with open(seq_fname, "r") as f:
    sequential_time = float(f.read().strip())

# ----------------------------------------------------------------------
# Make sure test/booktests is importable and load parsl_test_runner
# ----------------------------------------------------------------------
tests_dir = os.path.join(repo_root, "test", "booktests")
if tests_dir not in sys.path:
    sys.path.append(tests_dir)

import parsl_test_runner
parsl_test_runner = importlib.reload(parsl_test_runner)  # pick up latest edits

print("parsl_test_runner loaded from:", parsl_test_runner.__file__)
print(f"Repo root detected as: {repo_root}")
print(f"Tests dir: {tests_dir}")
print(f"Sequential baseline time: {sequential_time:.2f} s")
# Out:
# parsl_test_runner loaded from: /workspaces/QMCSoftware/test/booktests/parsl_test_runner.py
# Repo root detected as: /workspaces/QMCSoftware
# Tests dir: /workspaces/QMCSoftware/test/booktests
# Sequential baseline time: 730.49 s

# %% [markdown]
# ### 2.2 Create a Parsl Test Runner

# %%
import parsl_test_runner
import inspect

# See only functions
print("Functions:")
functions = inspect.getmembers(parsl_test_runner, inspect.isfunction)
for name, func in functions:
    print(f"- {name}")
print("\n" + "="*50)

# Get help on specific function
print("Help for execute_parallel_tests:")
help(parsl_test_runner.execute_parallel_tests)
# Out:
# Functions:
# - _derive_skipped_modules_from_notebooks
# - bash_app
# - execute_parallel_tests
# - generate_summary_report
# - get_runtime
# - main
# - optimal_schedule
# - print_notebook_booktest_coverage
#
# ==================================================
# Help for execute_parallel_tests:
# Help on function execute_parallel_tests in module parsl_test_runner:
#
# execute_parallel_tests()
#     Execute all tb_*.py booktests in parallel using Parsl.

# %% [markdown]
# ### 2.3 Run the Notebooks in Parallel with Parsl

# %%
import os
import time
import subprocess

tests_dir = os.path.join(repo_root, "test", "booktests")

for workers in [1, 2, 4, 8]:
    print("\n" + "=" * 60)
    print(f"=== RUNNING PARSL BOOKTESTS WITH {workers} WORKER(S) ===")

    par_fname = os.path.join(output_dir, f"parallel_times_{workers}.csv")

    if not os.path.exists(par_fname) or force_compute:
        cmd = [
            "python",
            "-u",
            "parsl_test_runner.py",
            "--workers",
            str(workers),
            "--print-coverage",   # prints skipped notebooks + totals once per run
        ]
        print("Command:", " ".join(cmd))
        print("CWD:", tests_dir)

        start_time = time.time()
        proc = subprocess.Popen(
            cmd,
            cwd=tests_dir,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1,
        )

        # Stream output live
        for line in proc.stdout:
            print(line, end="")

        proc.wait()
        parallel_time = time.time() - start_time

        if proc.returncode != 0:
            print(f"\nParsl test runner failed for workers={workers} "
                  f"with return code {proc.returncode}")
            continue

        speedup = sequential_time / parallel_time
        print(f"\nMeasured wall-clock for workers={workers}: {parallel_time:.2f} s")
        print(f"Measured speedup: {speedup:.2f}x")

        with open(par_fname, "w") as f:
            f.write("workers,times,speedup\n")
            f.write(f"{workers},{parallel_time:.2f},{speedup:.2f}\n")

        print(f"Saved results to {par_fname}")
    else:
        print(f"Skipping run for {workers} workers "
              f"(file already exists: {par_fname})")

print("\nAll Parsl runs completed. You can now run 03_visualize_speedup.ipynb.")
# Out:
# ============================================================
# === RUNNING PARSL BOOKTESTS WITH 1 WORKER(S) ===
# Command: python -u parsl_test_runner.py --workers 1 --print-coverage
# CWD: /workspaces/QMCSoftware/test/booktests
# Checking notebook ↔ booktest coverage...
#     Skipping demos/DAKOTA_Genz/dakota_genz.ipynb (requires large manual file / heavy memory use)
#     Skipping demos/talk_paper_demos/Argonne_Talk_2023_May/Argonne_2023_Talk_Figures.ipynb (heavy LaTeX + many figures; skipped in booktests_no_docker)
#     Skipping demos/talk_paper_demos/MCQMC2022_Article_Figures/MCQMC2022_Article_Figures.ipynb (MCQMC 2022 article figures; not run in CI)
#     Skipping demos/talk_paper_demos/ProbFailureSorokinRao/prob_failure_gp_ci.ipynb (prob_failure_gp_ci talk demo; heavy GP / prob. failure example)
#     Skipping demos/talk_paper_demos/Purdue_Talk_2023_March/Purdue_Talk_Figures.ipynb (Purdue 2023 talk figures; not a CI booktest target)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/01_sequential.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/02_parallel.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/03_visualize_speedup.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/pydata_chi_2023.ipynb (PyData Chicago 2023 talk notebook; demo-only)
# Total notebooks found:        35
# Total skipped explicitly (from .py creation):     9
# Total notebooks WITH tests:   26
# Total notebooks MISSING tests:0
# Booktests will be run for 26 notebooks.
#
# Configuring Parsl with max_workers=1
# Parsl configuration loaded successfully.
# Applied optimal LPT scheduling for 1 workers
# Estimated makespan: 752.9s (speedup: 1.00x)
# Found 26 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/26] tb_iris: PASSED
# tb_iris ...     Memory used: 0.13 GB.  Test time: 196.41 s
# ok
# [2/26] tb_elliptic_pde: PASSED
# tb_elliptic_pde ...     Memory used: 0.13 GB.  Test time: 104.20 s
# ok
# [3/26] tb_qei_demo_for_blog: PASSED
# tb_qei_demo_for_blog ...     Memory used: 0.13 GB.  Test time: 121.96 s
# ok
# [4/26] tb_asian_option_mlqmc: PASSED
# tb_asian_option_mlqmc ...     Memory used: 0.13 GB.  Test time: 111.42 s
# ok
# [5/26] tb_vectorized_qmc_bayes: PASSED
# tb_vectorized_qmc_bayes ...     Memory used: 0.12 GB.  Test time: 102.46 s
# ok
# [6/26] tb_digital_net_b2: PASSED
# tb_digital_net_b2 ...     Memory used: 0.13 GB.  Test time: 74.67 s
# ok
# [7/26] tb_ray_tracing: PASSED
# tb_ray_tracing ...     Memory used: 0.13 GB.  Test time: 71.70 s
# ok
# [8/26] tb_gaussian_diagnostics_demo: PASSED
# tb_gaussian_diagnostics_demo ...     Memory used: 0.13 GB.  Test time: 66.50 s
# ok
# [9/26] tb_lattice_random_generator: PASSED
# tb_lattice_random_generator ...     Memory used: 0.13 GB.  Test time: 40.87 s
# ok
# [10/26] tb_linear_scrambled_halton: PASSED
# tb_linear_scrambled_halton ...     Memory used: 0.13 GB.  Test time: 37.95 s
# ok
# [11/26] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
# tb_MCQMC_2020_QMC_Software_Tutorial ...     Memory used: 0.13 GB.  Test time: 34.65 s
# ok
# [12/26] tb_vectorized_qmc: PASSED
# tb_vectorized_qmc ...     Memory used: 0.12 GB.  Test time: 35.30 s
# ok
# [13/26] tb_plot_proj_function: PASSED
# tb_plot_proj_function ...     Memory used: 0.13 GB.  Test time: 28.89 s
# ok
# [14/26] tb_joss2025: PASSED
# tb_joss2025 ...     Memory used: 0.12 GB.  Test time: 431.06 s
# ok
# [15/26] tb_control_variates: PASSED
# tb_control_variates ...     Memory used: 0.13 GB.  Test time: 23.58 s
# ok
# [16/26] tb_pricing_options: PASSED
# tb_pricing_options ...     Memory used: 0.13 GB.  Test time: 22.57 s
# ok
# [17/26] tb_sample_scatter_plots: PASSED
# tb_sample_scatter_plots ...     Memory used: 0.13 GB.  Test time: 19.26 s
# ok
# [18/26] tb_nei_demo: PASSED
# tb_nei_demo ...     Memory used: 0.13 GB.  Test time: 18.43 s
# ok
# [19/26] tb_some_true_measures: PASSED
# tb_some_true_measures ...     Memory used: 0.13 GB.  Test time: 15.49 s
# ok
# [20/26] tb_why_add_q_to_mc_blog: PASSED
# tb_why_add_q_to_mc_blog ...     Memory used: 0.12 GB.  Test time: 10.05 s
# ok
# [21/26] tb_lebesgue_integration: PASSED
# tb_lebesgue_integration ...     Memory used: 0.13 GB.  Test time: 9.39 s
# ok
# [22/26] tb_qmcpy_intro: PASSED
# tb_qmcpy_intro ...     Memory used: 0.13 GB.  Test time: 7.78 s
# ok
# [23/26] tb_quickstart: PASSED
# tb_quickstart ...     Memory used: 0.13 GB.  Test time: 7.32 s
# ok
# [24/26] tb_gbm_demo: PASSED
# tb_gbm_demo ...     Memory used: 0.12 GB.  Test time: 3.19 s
# ok
# [25/26] tb_acm_toms_sorokin_2025: PASSED
# tb_acm_toms_sorokin_2025 ...     Memory used: 0.12 GB.  Test time: 3.06 s
# ok
# [26/26] tb_umbridge: PASSED
# tb_umbridge ...     Memory used: 0.11 GB.  Test time: 1.85 s
# ok
# ..........................
# ----------------------------------------------------------------------
# Ran 26 test modules in 442.036s
#
# OK
#
# Measured wall-clock for workers=1: 442.65 s
# Measured speedup: 1.65x
# Saved results to output/parallel_times_1.csv
#
# ============================================================
# === RUNNING PARSL BOOKTESTS WITH 2 WORKER(S) ===
# Command: python -u parsl_test_runner.py --workers 2 --print-coverage
# CWD: /workspaces/QMCSoftware/test/booktests
# Checking notebook ↔ booktest coverage...
#     Skipping demos/DAKOTA_Genz/dakota_genz.ipynb (requires large manual file / heavy memory use)
#     Skipping demos/talk_paper_demos/Argonne_Talk_2023_May/Argonne_2023_Talk_Figures.ipynb (heavy LaTeX + many figures; skipped in booktests_no_docker)
#     Skipping demos/talk_paper_demos/MCQMC2022_Article_Figures/MCQMC2022_Article_Figures.ipynb (MCQMC 2022 article figures; not run in CI)
#     Skipping demos/talk_paper_demos/ProbFailureSorokinRao/prob_failure_gp_ci.ipynb (prob_failure_gp_ci talk demo; heavy GP / prob. failure example)
#     Skipping demos/talk_paper_demos/Purdue_Talk_2023_March/Purdue_Talk_Figures.ipynb (Purdue 2023 talk figures; not a CI booktest target)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/01_sequential.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/02_parallel.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/03_visualize_speedup.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/pydata_chi_2023.ipynb (PyData Chicago 2023 talk notebook; demo-only)
# Total notebooks found:        35
# Total skipped explicitly (from .py creation):     9
# Total notebooks WITH tests:   26
# Total notebooks MISSING tests:0
# Booktests will be run for 26 notebooks.
#
# Configuring Parsl with max_workers=2
# Parsl configuration loaded successfully.
# Applied optimal LPT scheduling for 2 workers
# Estimated makespan: 376.4s (speedup: 2.00x)
# Found 26 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/26] tb_iris: PASSED
# tb_iris ...     Memory used: 0.13 GB.  Test time: 195.87 s
# ok
# [2/26] tb_elliptic_pde: PASSED
# tb_elliptic_pde ...     Memory used: 0.13 GB.  Test time: 106.76 s
# ok
# [3/26] tb_asian_option_mlqmc: PASSED
# tb_asian_option_mlqmc ...     Memory used: 0.13 GB.  Test time: 110.97 s
# ok
# [4/26] tb_qei_demo_for_blog: PASSED
# tb_qei_demo_for_blog ...     Memory used: 0.13 GB.  Test time: 120.79 s
# ok
# [5/26] tb_digital_net_b2: PASSED
# tb_digital_net_b2 ...     Memory used: 0.13 GB.  Test time: 72.58 s
# ok
# [6/26] tb_vectorized_qmc_bayes: PASSED
# tb_vectorized_qmc_bayes ...     Memory used: 0.12 GB.  Test time: 107.54 s
# ok
# [7/26] tb_gaussian_diagnostics_demo: PASSED
# tb_gaussian_diagnostics_demo ...     Memory used: 0.14 GB.  Test time: 68.32 s
# ok
# [8/26] tb_ray_tracing: PASSED
# tb_ray_tracing ...     Memory used: 0.13 GB.  Test time: 71.90 s
# ok
# [9/26] tb_linear_scrambled_halton: PASSED
# tb_linear_scrambled_halton ...     Memory used: 0.13 GB.  Test time: 37.06 s
# ok
# [10/26] tb_lattice_random_generator: PASSED
# tb_lattice_random_generator ...     Memory used: 0.13 GB.  Test time: 40.87 s
# ok
# [11/26] tb_vectorized_qmc: PASSED
# tb_vectorized_qmc ...     Memory used: 0.12 GB.  Test time: 34.89 s
# ok
# [12/26] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
# tb_MCQMC_2020_QMC_Software_Tutorial ...     Memory used: 0.13 GB.  Test time: 32.92 s
# ok
# [13/26] tb_joss2025: PASSED
# tb_joss2025 ...     Memory used: 0.12 GB.  Test time: 429.55 s
# ok
# [14/26] tb_plot_proj_function: PASSED
# tb_plot_proj_function ...     Memory used: 0.13 GB.  Test time: 28.35 s
# ok
# [15/26] tb_pricing_options: PASSED
# tb_pricing_options ...     Memory used: 0.13 GB.  Test time: 22.54 s
# ok
# [16/26] tb_control_variates: PASSED
# tb_control_variates ...     Memory used: 0.13 GB.  Test time: 22.53 s
# ok
# [17/26] tb_nei_demo: PASSED
# tb_nei_demo ...     Memory used: 0.13 GB.  Test time: 17.44 s
# ok
# [18/26] tb_sample_scatter_plots: PASSED
# tb_sample_scatter_plots ...     Memory used: 0.13 GB.  Test time: 18.71 s
# ok
# [19/26] tb_why_add_q_to_mc_blog: PASSED
# tb_why_add_q_to_mc_blog ...     Memory used: 0.11 GB.  Test time: 11.73 s
# ok
# [20/26] tb_some_true_measures: PASSED
# tb_some_true_measures ...     Memory used: 0.13 GB.  Test time: 15.36 s
# ok
# [21/26] tb_lebesgue_integration: PASSED
# tb_lebesgue_integration ...     Memory used: 0.13 GB.  Test time: 8.53 s
# ok
# [22/26] tb_qmcpy_intro: PASSED
# tb_qmcpy_intro ...     Memory used: 0.13 GB.  Test time: 7.27 s
# ok
# [23/26] tb_quickstart: PASSED
# tb_quickstart ...     Memory used: 0.13 GB.  Test time: 7.24 s
# ok
# [24/26] tb_gbm_demo: PASSED
# tb_gbm_demo ...     Memory used: 0.12 GB.  Test time: 3.27 s
# ok
# [25/26] tb_umbridge: PASSED
# tb_umbridge ...     Memory used: 0.12 GB.  Test time: 2.13 s
# ok
# [26/26] tb_acm_toms_sorokin_2025: PASSED
# tb_acm_toms_sorokin_2025 ...     Memory used: 0.12 GB.  Test time: 5.66 s
# ok
# ..........................
# ----------------------------------------------------------------------
# Ran 26 test modules in 440.514s
#
# OK
#
# Measured wall-clock for workers=2: 441.11 s
# Measured speedup: 1.66x
# Saved results to output/parallel_times_2.csv
#
# ============================================================
# === RUNNING PARSL BOOKTESTS WITH 4 WORKER(S) ===
# Command: python -u parsl_test_runner.py --workers 4 --print-coverage
# CWD: /workspaces/QMCSoftware/test/booktests
# Checking notebook ↔ booktest coverage...
#     Skipping demos/DAKOTA_Genz/dakota_genz.ipynb (requires large manual file / heavy memory use)
#     Skipping demos/talk_paper_demos/Argonne_Talk_2023_May/Argonne_2023_Talk_Figures.ipynb (heavy LaTeX + many figures; skipped in booktests_no_docker)
#     Skipping demos/talk_paper_demos/MCQMC2022_Article_Figures/MCQMC2022_Article_Figures.ipynb (MCQMC 2022 article figures; not run in CI)
#     Skipping demos/talk_paper_demos/ProbFailureSorokinRao/prob_failure_gp_ci.ipynb (prob_failure_gp_ci talk demo; heavy GP / prob. failure example)
#     Skipping demos/talk_paper_demos/Purdue_Talk_2023_March/Purdue_Talk_Figures.ipynb (Purdue 2023 talk figures; not a CI booktest target)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/01_sequential.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/02_parallel.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/03_visualize_speedup.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/pydata_chi_2023.ipynb (PyData Chicago 2023 talk notebook; demo-only)
# Total notebooks found:        35
# Total skipped explicitly (from .py creation):     9
# Total notebooks WITH tests:   26
# Total notebooks MISSING tests:0
# Booktests will be run for 26 notebooks.
#
# Configuring Parsl with max_workers=4
# Parsl configuration loaded successfully.
# Applied optimal LPT scheduling for 4 workers
# Estimated makespan: 188.5s (speedup: 3.99x)
# Found 26 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/26] tb_iris: PASSED
# tb_iris ...     Memory used: 0.13 GB.  Test time: 194.49 s
# ok
# [2/26] tb_elliptic_pde: PASSED
# tb_elliptic_pde ...     Memory used: 0.13 GB.  Test time: 121.39 s
# ok
# [3/26] tb_qei_demo_for_blog: PASSED
# tb_qei_demo_for_blog ...     Memory used: 0.13 GB.  Test time: 126.78 s
# ok
# [4/26] tb_asian_option_mlqmc: PASSED
# tb_asian_option_mlqmc ...     Memory used: 0.13 GB.  Test time: 112.71 s
# ok
# [5/26] tb_linear_scrambled_halton: PASSED
# tb_linear_scrambled_halton ...     Memory used: 0.13 GB.  Test time: 40.46 s
# ok
# [6/26] tb_ray_tracing: PASSED
# tb_ray_tracing ...     Memory used: 0.13 GB.  Test time: 73.00 s
# ok
# [7/26] tb_digital_net_b2: PASSED
# tb_digital_net_b2 ...     Memory used: 0.13 GB.  Test time: 73.81 s
# ok
# [8/26] tb_vectorized_qmc_bayes: PASSED
# tb_vectorized_qmc_bayes ...     Memory used: 0.12 GB.  Test time: 103.66 s
# ok
# [9/26] tb_plot_proj_function: PASSED
# tb_plot_proj_function ...     Memory used: 0.13 GB.  Test time: 28.22 s
# ok
# [10/26] tb_lattice_random_generator: PASSED
# tb_lattice_random_generator ...     Memory used: 0.13 GB.  Test time: 39.87 s
# ok
# [11/26] tb_gaussian_diagnostics_demo: PASSED
# tb_gaussian_diagnostics_demo ...     Memory used: 0.13 GB.  Test time: 65.47 s
# ok
# [12/26] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
# tb_MCQMC_2020_QMC_Software_Tutorial ...     Memory used: 0.13 GB.  Test time: 34.93 s
# ok
# [13/26] tb_sample_scatter_plots: PASSED
# tb_sample_scatter_plots ...     Memory used: 0.13 GB.  Test time: 20.60 s
# ok
# [14/26] tb_vectorized_qmc: PASSED
# tb_vectorized_qmc ...     Memory used: 0.12 GB.  Test time: 36.72 s
# ok
# [15/26] tb_joss2025: PASSED
# tb_joss2025 ...     Memory used: 0.12 GB.  Test time: 427.63 s
# ok
# [16/26] tb_control_variates: PASSED
# tb_control_variates ...     Memory used: 0.13 GB.  Test time: 21.44 s
# ok
# [17/26] tb_nei_demo: PASSED
# tb_nei_demo ...     Memory used: 0.13 GB.  Test time: 18.22 s
# ok
# [18/26] tb_pricing_options: PASSED
# tb_pricing_options ...     Memory used: 0.13 GB.  Test time: 20.63 s
# ok
# [19/26] tb_some_true_measures: PASSED
# tb_some_true_measures ...     Memory used: 0.13 GB.  Test time: 14.70 s
# ok
# [20/26] tb_why_add_q_to_mc_blog: PASSED
# tb_why_add_q_to_mc_blog ...     Memory used: 0.12 GB.  Test time: 9.61 s
# ok
# [21/26] tb_acm_toms_sorokin_2025: PASSED
# tb_acm_toms_sorokin_2025 ...     Memory used: 0.12 GB.  Test time: 3.49 s
# ok
# [22/26] tb_lebesgue_integration: PASSED
# tb_lebesgue_integration ...     Memory used: 0.13 GB.  Test time: 7.34 s
# ok
# [23/26] tb_gbm_demo: PASSED
# tb_gbm_demo ...     Memory used: 0.12 GB.  Test time: 3.27 s
# ok
# [24/26] tb_qmcpy_intro: PASSED
# tb_qmcpy_intro ...     Memory used: 0.13 GB.  Test time: 7.12 s
# ok
# [25/26] tb_quickstart: PASSED
# tb_quickstart ...     Memory used: 0.13 GB.  Test time: 6.62 s
# ok
# [26/26] tb_umbridge: PASSED
# tb_umbridge ...     Memory used: 0.12 GB.  Test time: 2.12 s
# ok
# ..........................
# ----------------------------------------------------------------------
# Ran 26 test modules in 438.888s
#
# OK
#
# Measured wall-clock for workers=4: 439.49 s
# Measured speedup: 1.66x
# Saved results to output/parallel_times_4.csv
#
# ============================================================
# === RUNNING PARSL BOOKTESTS WITH 8 WORKER(S) ===
# Command: python -u parsl_test_runner.py --workers 8 --print-coverage
# CWD: /workspaces/QMCSoftware/test/booktests
# Checking notebook ↔ booktest coverage...
#     Skipping demos/DAKOTA_Genz/dakota_genz.ipynb (requires large manual file / heavy memory use)
#     Skipping demos/talk_paper_demos/Argonne_Talk_2023_May/Argonne_2023_Talk_Figures.ipynb (heavy LaTeX + many figures; skipped in booktests_no_docker)
#     Skipping demos/talk_paper_demos/MCQMC2022_Article_Figures/MCQMC2022_Article_Figures.ipynb (MCQMC 2022 article figures; not run in CI)
#     Skipping demos/talk_paper_demos/ProbFailureSorokinRao/prob_failure_gp_ci.ipynb (prob_failure_gp_ci talk demo; heavy GP / prob. failure example)
#     Skipping demos/talk_paper_demos/Purdue_Talk_2023_March/Purdue_Talk_Figures.ipynb (Purdue 2023 talk figures; not a CI booktest target)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/01_sequential.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/02_parallel.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/parsel_fest_2025/03_visualize_speedup.ipynb (helper notebook for parsl_fest_2025; not a standalone booktest)
#     Skipping demos/talk_paper_demos/pydata_chi_2023.ipynb (PyData Chicago 2023 talk notebook; demo-only)
# Total notebooks found:        35
# Total skipped explicitly (from .py creation):     9
# Total notebooks WITH tests:   26
# Total notebooks MISSING tests:0
# Booktests will be run for 26 notebooks.
#
# Configuring Parsl with max_workers=8
# Parsl configuration loaded successfully.
# Applied optimal LPT scheduling for 8 workers
# Estimated makespan: 138.1s (speedup: 5.45x)
# Found 26 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/26] tb_iris: PASSED
# tb_iris ...     Memory used: 0.13 GB.  Test time: 197.52 s
# ok
# [2/26] tb_elliptic_pde: PASSED
# tb_elliptic_pde ...     Memory used: 0.13 GB.  Test time: 102.22 s
# ok
# [3/26] tb_qei_demo_for_blog: PASSED
# tb_qei_demo_for_blog ...     Memory used: 0.13 GB.  Test time: 123.60 s
# ok
# [4/26] tb_asian_option_mlqmc: PASSED
# tb_asian_option_mlqmc ...     Memory used: 0.13 GB.  Test time: 112.23 s
# ok
# [5/26] tb_vectorized_qmc_bayes: PASSED
# tb_vectorized_qmc_bayes ...     Memory used: 0.12 GB.  Test time: 103.50 s
# ok
# [6/26] tb_digital_net_b2: PASSED
# tb_digital_net_b2 ...     Memory used: 0.13 GB.  Test time: 71.96 s
# ok
# [7/26] tb_ray_tracing: PASSED
# tb_ray_tracing ...     Memory used: 0.13 GB.  Test time: 71.69 s
# ok
# [8/26] tb_gaussian_diagnostics_demo: PASSED
# tb_gaussian_diagnostics_demo ...     Memory used: 0.13 GB.  Test time: 67.06 s
# ok
# [9/26] tb_quickstart: PASSED
# tb_quickstart ...     Memory used: 0.13 GB.  Test time: 9.52 s
# ok
# [10/26] tb_control_variates: PASSED
# tb_control_variates ...     Memory used: 0.13 GB.  Test time: 21.27 s
# ok
# [11/26] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
# tb_MCQMC_2020_QMC_Software_Tutorial ...     Memory used: 0.13 GB.  Test time: 35.01 s
# ok
# [12/26] tb_linear_scrambled_halton: PASSED
# tb_linear_scrambled_halton ...     Memory used: 0.13 GB.  Test time: 38.52 s
# ok
# [13/26] tb_lattice_random_generator: PASSED
# tb_lattice_random_generator ...     Memory used: 0.13 GB.  Test time: 39.94 s
# ok
# [14/26] tb_lebesgue_integration: PASSED
# tb_lebesgue_integration ...     Memory used: 0.13 GB.  Test time: 9.53 s
# ok
# [15/26] tb_joss2025: PASSED
# tb_joss2025 ...     Memory used: 0.12 GB.  Test time: 425.51 s
# ok
# [16/26] tb_plot_proj_function: PASSED
# tb_plot_proj_function ...     Memory used: 0.13 GB.  Test time: 28.48 s
# ok
# [17/26] tb_vectorized_qmc: PASSED
# tb_vectorized_qmc ...     Memory used: 0.12 GB.  Test time: 33.80 s
# ok
# [18/26] tb_acm_toms_sorokin_2025: PASSED
# tb_acm_toms_sorokin_2025 ...     Memory used: 0.12 GB.  Test time: 4.20 s
# ok
# [19/26] tb_nei_demo: PASSED
# tb_nei_demo ...     Memory used: 0.13 GB.  Test time: 19.62 s
# ok
# [20/26] tb_pricing_options: PASSED
# tb_pricing_options ...     Memory used: 0.13 GB.  Test time: 21.33 s
# ok
# [21/26] tb_sample_scatter_plots: PASSED
# tb_sample_scatter_plots ...     Memory used: 0.13 GB.  Test time: 17.13 s
# ok
# [22/26] tb_some_true_measures: PASSED
# tb_some_true_measures ...     Memory used: 0.13 GB.  Test time: 13.98 s
# ok
# [23/26] tb_qmcpy_intro: PASSED
# tb_qmcpy_intro ...     Memory used: 0.13 GB.  Test time: 7.81 s
# ok
# [24/26] tb_why_add_q_to_mc_blog: PASSED
# tb_why_add_q_to_mc_blog ...     Memory used: 0.12 GB.  Test time: 8.56 s
# ok
# [25/26] tb_umbridge: PASSED
# tb_umbridge ...     Memory used: 0.12 GB.  Test time: 1.84 s
# ok
# [26/26] tb_gbm_demo: PASSED
# tb_gbm_demo ...     Memory used: 0.12 GB.  Test time: 5.94 s
# ok
# ..........................
# ----------------------------------------------------------------------
# Ran 26 test modules in 436.500s
#
# OK
#
# Measured wall-clock for workers=8: 437.10 s
# Measured speedup: 1.67x
# Saved results to output/parallel_times_8.csv
#
# All Parsl runs completed. You can now run 03_visualize_speedup.ipynb.

# %%
# !date
# !ls -ltr output
# Out:
# Wed Dec  3 02:43:01 UTC 2025
# total 24
# -rw-rw-rw- 1 codespace codespace    8 Dec  3 02:06 sequential_time.csv
# -rw-rw-rw- 1 codespace codespace 1708 Dec  3 02:12 sequential_times_detail.csv
# -rw-rw-rw- 1 codespace codespace   36 Dec  3 02:20 parallel_times_1.csv
# -rw-rw-rw- 1 codespace codespace   36 Dec  3 02:27 parallel_times_2.csv
# -rw-rw-rw- 1 codespace codespace   36 Dec  3 02:35 parallel_times_4.csv
# -rw-rw-rw- 1 codespace codespace   36 Dec  3 02:42 parallel_times_8.csv

# %%
import platform

if platform.system().lower() == 'linux':
    # !uname -a
    # !nproc --all
    # !awk '/MemTotal/ {printf "%.2f GB\n", $2/1024/1024}' /proc/meminfo
# Out:
# Linux codespaces-927f92 6.8.0-1030-azure #35~22.04.1-Ubuntu SMP Mon May 26 18:08:30 UTC 2025 x86_64 x86_64 x86_64 GNU/Linux
# 16
# 62.80 GB
