# %% [markdown]
# # [ParslFest 2025](https://parsl-project.org/parslfest/parslfest2025.html)
#
# # [Accelerating QMCpy Notebook Tests with Parsl](https://www.figma.com/slides/k7EUosssNluMihkYTLuh1F/Parsl-Testbook-Speedup?node-id=1-37&t=WnKcu2QYO8JXvtpP-0)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QMCSoftware/QMCSoftware/blob/develop/demos/talk_paper_demos/parsel_fest_2025/parsl_fest_2025.ipynb)
#
# Joshua Herman and Sou-Cheng Choi, QMCPy Developers
#
# Aug 28 -- 29, 2025
#
# Updated: Nov 30, 2025
#
#
# **Requirements**:
#
# * testbook : `pip install testbook==0.4.2`
# * Parsl: `pip install parsl==2025.7.28`

# %%
try:
    import parsl as pl
except ModuleNotFoundError:
    # !pip install -q parsl

# %%
import sys
import os
import time
import parsl as pl

# Ensure the path to the booktests directory is included (robust finder)
def _find_repo_root(start=os.getcwd()):
    cur = start
    while True:
        if os.path.exists(os.path.join(cur, 'pyproject.toml')):
            return cur
        parent = os.path.dirname(cur)
        if parent == cur:
            raise FileNotFoundError('repo root not found')
        cur = parent

sys.path.append(os.path.join(_find_repo_root(), 'test', 'booktests'))

# Configuration flags
force_compute = True
is_debug = False

# Create output directory if it doesn't exist
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## 2. Parsl
#
# 1. Install and Configure Parsl
# 2. Run the tests in parallel with Parsl

# %% [markdown]
# ### 2.1 Configure Parsl

# %%
from parsl.configs.htex_local import config

config.max_workers = 2
if not pl.config:
    pl.load(config)
    print("Parsl loaded with memory limits")
else:
    print("Parsl already configured")
# Out:
# Parsl already configured

# %% [markdown]
# ### 2.2 Create a Parsl Test Runner

# %%
import parsl_test_runner
import inspect

# See only functions
print("Functions:")
functions = inspect.getmembers(parsl_test_runner, inspect.isfunction)
for name, func in functions:
    print(f"- {name}")
print("\n" + "="*50)

# Get help on specific function
print("Help for execute_parallel_tests:")
help(parsl_test_runner.execute_parallel_tests)
# Out:
# Functions:
# - bash_app
# - execute_parallel_tests
# - generate_summary_report
# - main
# - reload_parsl_config
#
# ==================================================
# Help for execute_parallel_tests:
# Help on function execute_parallel_tests in module parsl_test_runner:
#
# execute_parallel_tests()
#     Execute all testbook tests in parallel using Parsl

# %% [markdown]
# ### 2.3 Run the Notebooks in Parallel with Parsl

# %%
par_fname = os.path.join(output_dir, f"parallel_times_{config.max_workers}.csv")
if (not os.path.exists(par_fname)) or force_compute:
    start_time2 = time.time()
    if is_debug:
        !(cd ../../.. && make booktests_parallel_no_docker TESTS="tb_quickstart tb_qmcpy_intro tb_quickstart tb_qmcpy_intro")
    else:
        !(cd ../../.. && make booktests_parallel_no_docker)
    parallel_time = time.time() - start_time2

    # read sequential time from file in output_dir
    seq_fname = os.path.join(output_dir, "sequential_time.csv")
    with open(seq_fname, "r") as f:
        sequential_time = float(f.read().strip())
        
    # compute speedup
    speedup = sequential_time / parallel_time
    print(f"Sequential time:  {sequential_time:.2f} seconds")
    print(f"Parallel time:    {parallel_time:.2f} seconds")
    print(f"Speedup by Parsl: {speedup:.2f}")

    # save parallel time to a file in output_dir
    with open(par_fname, "w") as f:
        f.write(f"workers,times,speedup\n")
        f.write(f"{config.max_workers},{parallel_time:.2f},{speedup:.2f}\n")
# Out:
# rm -fr demos/.ipynb_checkpoints/*checkpoint.ipynb && \
# find demos -name '*.ipynb' | while read nb; do \
# 	base=$(basename "$nb" .ipynb); \
# 	test_base=$(echo "$base" | sed 's/[-.]/_/g'); \
# 	if [ "$base" != "parsl_fest_2025" ] && [ "$base" != "01_sequential" ] && [ "$base" != "02_parallel" ] && [ "$base" != "03_visualize_speedup" ] && ! ls test/booktests/tb_"$test_base".py > /dev/null 2>&1; then \
# 		echo "    Missing test for: $nb -> Expected: test/booktests/tb_$test_base.py"; \
# 	fi; \
# done
# Total notebooks:  35
# Total test files: 32
#
# Generating missing booktest files...
# cd test/booktests/ && python generate_test.py --check-missing
# No missing test files found.
# rm -fr test/booktests/.ipynb_checkpoints/
# chmod +x scripts/find_local_only_folders.sh > /dev/null 2>&1
# for f in ; do \
# 	rm -f "$f"; > /dev/null 2>&1; \
# done
#
# Notebook tests with Parsl
# pip install -q -e ".[test]"  && \
# cd test/booktests/ && \
# rm -fr *.eps *.jpg *.pdf *.png *.part *.txt *.log && rm -fr logs && rm -fr runinfo prob_failure_gp_ci_plots && \
# PYTHONWARNINGS="ignore::UserWarning,ignore::DeprecationWarning,ignore::FutureWarning,ignore::ImportWarning" \
# python parsl_test_runner.py  -v --failfast && \
# cd ../..
# Parsl configuration loaded successfully.
# Found 32 test modules to execute in parallel...
# All tests submitted to Parsl executor...
# [1/32] tb_pricing_options: PASSED
#     Memory used: 0.09 GB.  Test time: 22.62 s
#
# [2/32] tb_gaussian_diagnostics_demo: PASSED
#     Memory used: 0.10 GB.  Test time: 77.11 s
#
# [3/32] tb_some_true_measures: PASSED
#     Memory used: 0.09 GB.  Test time: 16.93 s
#
# [4/32] tb_quickstart: PASSED
#     Memory used: 0.09 GB.  Test time: 8.27 s
#
# [5/32] tb_nei_demo: PASSED
#     Memory used: 0.09 GB.  Test time: 18.19 s
#
# Test tb_MCQMC2022_Article_Figures failed once with error: bash_app run_single_test failed with unix exit code 5. Retrying...
# [6/32] tb_MCQMC2022_Article_Figures: FAILED
# [7/32] tb_lebesgue_integration: PASSED
#     Memory used: 0.09 GB.  Test time: 9.65 s
#
# [8/32] tb_acm_toms_sorokin_2025: PASSED
#     Memory used: 0.08 GB.  Test time: 3.68 s
#
# [9/32] tb_linear_scrambled_halton: PASSED
#     Memory used: 0.09 GB.  Test time: 38.90 s
#
# [10/32] tb_iris: PASSED
#     Memory used: 0.09 GB.  Test time: 208.65 s
#
# [11/32] tb_qmcpy_intro: PASSED
#     Memory used: 0.09 GB.  Test time: 9.58 s
#
# [12/32] tb_digital_net_b2: PASSED
#     Memory used: 0.09 GB.  Test time: 78.38 s
#
# Test tb_Argonne_2023_Talk_Figures failed once with error: bash_app run_single_test failed with unix exit code 5. Retrying...
# [13/32] tb_Argonne_2023_Talk_Figures: FAILED
# [14/32] tb_plot_proj_function: PASSED
#     Memory used: 0.09 GB.  Test time: 29.84 s
#
# [15/32] tb_ray_tracing: PASSED
#     Memory used: 0.09 GB.  Test time: 76.80 s
#
# Test tb_prob_failure_gp_ci failed once with error: bash_app run_single_test failed with unix exit code 1. Retrying...
# [16/32] tb_prob_failure_gp_ci: FAILED
# [17/32] tb_asian_option_mlqmc: PASSED
#     Memory used: 0.09 GB.  Test time: 121.26 s
#
# [18/32] tb_lattice_random_generator: PASSED
#     Memory used: 0.09 GB.  Test time: 41.40 s
#
# [19/32] tb_gbm_demo: PASSED
#     Memory used: 0.08 GB.  Test time: 4.01 s
#
# [20/32] tb_MCQMC_2020_QMC_Software_Tutorial: PASSED
#     Memory used: 0.09 GB.  Test time: 37.42 s
#
# [21/32] tb_sample_scatter_plots: PASSED
#     Memory used: 0.09 GB.  Test time: 20.85 s
#
# [22/32] tb_joss2025: PASSED
#     Memory used: 0.08 GB.  Test time: 27.35 s
#
# [23/32] tb_why_add_q_to_mc_blog: PASSED
#     Memory used: 0.08 GB.  Test time: 11.63 s
#
# [24/32] tb_vectorized_qmc_bayes: PASSED
#     Memory used: 0.08 GB.  Test time: 103.28 s
#
# [25/32] tb_umbridge: PASSED
#     Memory used: 0.08 GB.  Test time: 2.79 s
#
# [26/32] tb_vectorized_qmc: PASSED
#     Memory used: 0.08 GB.  Test time: 38.03 s
#
# [27/32] tb_pydata_chi_2023: PASSED
#     Memory used: 0.08 GB.  Test time: 42.40 s
#
# [28/32] tb_elliptic_pde: PASSED
#     Memory used: 0.09 GB.  Test time: 141.32 s
#
# Test tb_dakota_genz failed once with error: bash_app run_single_test failed with unix exit code 5. Retrying...
# [29/32] tb_dakota_genz: FAILED
# [30/32] tb_control_variates: PASSED
#     Memory used: 0.09 GB.  Test time: 25.59 s
#
# [31/32] tb_qei_demo_for_blog: PASSED
#     Memory used: 0.09 GB.  Test time: 116.57 s
#
# Test tb_Purdue_Talk_Figures failed once with error: bash_app run_single_test failed with unix exit code 5. Retrying...
# [32/32] tb_Purdue_Talk_Figures: FAILED
# .....F......F..F............F..F
# ----------------------------------------------------------------------
# Ran 32 test modules in 226.431s
#
# FAILED (failures=5)
#
# FAILURES:
# ======================================================================
# FAIL: tb_MCQMC2022_Article_Figures
# ----------------------------------------------------------------------
# Error: FAILED after retry: bash_app run_single_test failed with unix exit code 5
#
# FAIL: tb_Argonne_2023_Talk_Figures
# ----------------------------------------------------------------------
# Error: FAILED after retry: bash_app run_single_test failed with unix exit code 5
#
# FAIL: tb_prob_failure_gp_ci
# ----------------------------------------------------------------------
# Error: FAILED after retry: bash_app run_single_test failed with unix exit code 1
#
# FAIL: tb_dakota_genz
# ----------------------------------------------------------------------
# Error: FAILED after retry: bash_app run_single_test failed with unix exit code 5
#
# FAIL: tb_Purdue_Talk_Figures
# ----------------------------------------------------------------------
# Error: FAILED after retry: bash_app run_single_test failed with unix exit code 5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 12
#      10 # read sequential time from file in output_dir
#      11 seq_fname = os.path.join(output_dir, "sequential_time.csv")
# ---> 12 with open(seq_fname, "r") as f:
#      13     sequential_time = float(f.read().strip())
#      15 # compute speedup
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/sequential_time.csv'

# %%
# !date
# !ls -ltr output
