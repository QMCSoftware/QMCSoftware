# %% [markdown]
# # Importing Libraries
#
# The following statements import the necessary libraries needed.

# %%
import qmcpy as qp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Lookback Option Class
#
# The following tests the `LookBackOption` class.

# %%
dims = 16
abs_tol = 1e-3

aco = qp.LookBackOption(qp.Sobol(dims), volatility=0.2, start_price=100, interest_rate=.05, call_put='call')
# aco = qp.LookBackOption(volatility=0.2, start_price=100, interest_rate=.05, call_put='put') # Put test
kde, a, b, approx_solution, data, fig, axes = qp.CubQMCSobolG(aco, abs_tol).density_estimation(True)
print("Lookback Option value: %.5f (to within %1.e) with %.f paths"% (approx_solution, abs_tol, data.n_total))
plt.show()
# Out:
# Lookback Option value: 14.40591 (to within 1e-03) with 262144 paths

# %% [markdown]
# # American Option Class
#
# The following tests the `AmericanOption` class.

# %%
dims = 16
abs_tol = 1e-3

aco = qp.AmericanOption(sampler=qp.Sobol(4), volatility=0.2, start_price=100, strike_price=150, interest_rate=0.05, call_put='call', observations=4)
# breakpoint()
kde, a, b, approx_solution, data, fig, axes = qp.CubQMCSobolG(aco, abs_tol).density_estimation(True)
# kde, a, b, approx_solution, data = qp.CubQMCSobolG(aco, abs_tol).density_estimation()
print("American Option value: %.5f (to within %1.e) with %.f paths"% (approx_solution, abs_tol, data.n_total))

# fig.show()
plt.show()
# Out:
# American Option value: 48.06709 (to within 1e-03) with 262144 paths

# %% [markdown]
# # European Option
#
# The following tests the `european_option` class.

# %%
dims = 16
abs_tol = 1e-3

aco = qp.EuropeanOption(qp.Sobol(dims), volatility=0.2, start_price=100, strike_price=150, interest_rate=.05, call_put='call')
kde, a, b, approx_solution, data, fig, axes = qp.CubQMCSobolG(aco, abs_tol).density_estimation(True)
print("European Option value: %.5f (to within %1.e) with %.f paths"% (approx_solution, abs_tol, data.n_total))

plt.show()
# Out:
# European Option value: 0.35956 (to within 1e-03) with 131072 paths

# %% [markdown]
# # Asian Option Class
#
# The following tests for the `asian_option` class. For some reason only `put` works, `call` doesn't. An error to fix.

# %%
dims = 16
abs_tol = 1e-3

aco = qp.AsianOption(qp.Sobol(dims, seed=7), volatility=0.2, start_price=100, strike_price=150, interest_rate=.05, call_put='put')
kde, a, b, approx_solution, data, fig, axes = qp.CubQMCSobolG(aco, abs_tol).density_estimation(True)
print("Asian Option value: %.5f (to within %1.e) with %.f paths"% (approx_solution, abs_tol, data.n_total))

plt.show()
# Out:
# Asian Option value: 45.14621 (to within 1e-03) with 16384 paths

# %% [markdown]
# # Barrier Option

# %%
dims = 16
abs_tol = 1e-3
barrier = 150
inOutType = 'in'

aco = qp.BarrierOption(qp.Sobol(dims), volatility=0.2, start_price=100, strike_price=130, barrier_price=barrier,
                       interest_rate=0.05, call_put='call', in_out='in')
kde, a, b, approx_solution, data, fig, axes = qp.CubQMCSobolG(aco, abs_tol).density_estimation(True)
print("Lookback Option value: %.5f (to within %1.e) with %.f paths"% (approx_solution, abs_tol, data.n_total))
plt.show()
# Out:
# Lookback Option value: 1.06634 (to within 1e-03) with 524288 paths
