# %%
from pandas import read_csv
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline

# %%
distrib_names = ['IIDStdUniform','IIDStdGaussian','Lattice','Sobol']

# %% [markdown]
# # Absolute Tolerance Plots

# %%
df_abstols = read_csv('../outputs/comparison_tests/abs_tol.csv')
df_abstols.loc[:10]
# Out:
#     Unnamed: 0  abs_tol  IIDStdUniform_solution  IIDStdGaussian_solution  \
# 0            0   0.0005                     NaN                      NaN
# 1            1   0.0010                     NaN                 2.168435
# 2            2   0.0015                2.168478                 2.168667
# 3            3   0.0020                2.168726                 2.168156
# 4            4   0.0025                2.168246                 2.168391
# 5            5   0.0030                2.167688                 2.168159
# 6            6   0.0035                2.168744                 2.168334
# 7            7   0.0040                2.169340                 2.167062
# 8            8   0.0045                2.169133                 2.167648
# 9            9   0.0050                2.169428                 2.168410
# 10          10   0.0055                2.169046                 2.168017
#
#     Lattice_solution  Sobol_solution  IIDStdUniform_time  IIDStdGaussian_time  \
# 0           2.168330        2.168169                 NaN                  NaN
# 1           2.168415        2.168439                 NaN             4.351999
# 2           2.168270        2.168439            6.385700             1.720378
# 3           2.168270        2.168439            3.523342             0.960421
# 4           2.168270        2.168709            2.781954             0.790689
# 5           2.168270        2.168709            1.898693             0.551129
# 6           2.168270        2.168709            1.396817             0.394115
# 7           2.168165        2.168709            1.055029             0.299040
# 8           2.168165        2.168315            0.833217             0.241870
# 9           2.168165        2.168315            0.699309             0.198575
# 10          2.168165        2.168315            0.566983             0.164632
#
#     Lattice_time  Sobol_time  IIDStdUniform_n  IIDStdGaussian_n  Lattice_n  \
# 0       0.078834    0.149196              NaN               NaN     4096.0
# 1       0.053851    0.151899              NaN        42585463.0     2048.0
# 2       0.018600    0.037369       18218512.0        18927157.0     1024.0
# 3       0.017907    0.035862       10248137.0        10646750.0     1024.0
# 4       0.023561    0.029379        6558992.0         6814105.0     1024.0
# 5       0.024789    0.029811        4555012.0         4732174.0     1024.0
# 6       0.024104    0.028449        3346676.0         3476835.0     1024.0
# 7       0.014392    0.028136        2562419.0         2662072.0      512.0
# 8       0.014321    0.018833        2024735.0         2103473.0      512.0
# 9       0.016500    0.019176        1640132.0         1703911.0      512.0
# 10      0.015323    0.020137        1355570.0         1408279.0      512.0
#
#     Sobol_n
# 0    8192.0
# 1    2048.0
# 2    2048.0
# 3    2048.0
# 4    1024.0
# 5    1024.0
# 6    1024.0
# 7    1024.0
# 8     512.0
# 9     512.0
# 10    512.0

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
abstols = df_abstols['abs_tol'].values
for distrib_name in distrib_names:
    times = df_abstols[distrib_name+'_time'].values
    n_total = df_abstols[distrib_name+'_n'].values
    ax[0].loglog(abstols, times, label=distrib_name)
    ax[1].loglog(abstols, n_total, label=distrib_name)
ax[0].legend(loc='upper left')
ax[0].set_xlim(ax[0].get_xlim()[::-1])
ax[1].set_xlim(ax[1].get_xlim()[::-1])
ax[0].set_xlabel('Absolute Tolerance')
ax[0].set_ylabel('Runtime')
ax[1].set_xlabel('Absolute Tolerance')
ax[1].set_ylabel('Total Samples')
fig.suptitle('Comparing Absolute Tolerances')
plt.savefig('../outputs/comparison_tests/abstols_plot.png',dpi=200)

# %% [markdown]
# # Dimension Plots

# %%
df_dimensions = read_csv('../outputs/comparison_tests/dimension.csv')
df_dimensions
# Out:
#    Unnamed: 0  dimension  IIDStdUniform_solution  IIDStdGaussian_solution  \
# 0           0        1.0                1.384495                 1.405787
# 1           1        2.0                1.798584                 1.826546
# 2           2        3.0                2.165223                 2.178902
# 3           3        4.0                2.211953                 2.172499
# 4           4        5.0                1.167095                 1.139966
# 5           5        6.0               -2.320012                -2.322263
# 6           6        7.0              -11.059960               -11.057672
# 7           7        8.0              -30.601444               -30.587924
#
#    Lattice_solution  Sobol_solution  IIDStdUniform_time  IIDStdGaussian_time  \
# 0          1.372271        1.372271            0.002228             0.001451
# 1          1.802262        1.804513            0.003338             0.001564
# 2          2.171712        2.147651            0.008479             0.002877
# 3          2.159593        2.159230            0.036994             0.009878
# 4          1.131887        1.131728            0.134496             0.024843
# 5         -2.331987       -2.329818            0.416805             0.101703
# 6        -11.058640      -11.031947            1.678053             0.304505
# 7        -30.612701      -30.616220            5.359342             0.973505
#
#    Lattice_time  Sobol_time  IIDStdUniform_n  IIDStdGaussian_n  Lattice_n  \
# 0      0.001967    0.007814           1390.0            1281.0       16.0
# 1      0.003607    0.007930           4843.0            4641.0       32.0
# 2      0.004147    0.007478          16909.0           17546.0       64.0
# 3      0.013082    0.011961          65037.0           63083.0      256.0
# 4      0.007921    0.011166         225732.0          205754.0      256.0
# 5      0.014679    0.028992         679937.0          716993.0      512.0
# 6      0.036090    0.054251        2167093.0         1889258.0     1024.0
# 7      0.113050    0.213967        6736067.0         5541812.0     4096.0
#
#    Sobol_n
# 0     16.0
# 1     32.0
# 2     32.0
# 3    128.0
# 4    256.0
# 5   1024.0
# 6   2048.0
# 7   8192.0

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
dimensions = df_dimensions['dimension']
for distrib_name in distrib_names:
    times = df_dimensions[distrib_name+'_time'].values
    n_total = df_dimensions[distrib_name+'_n'].values
    ax[0].plot(dimensions, times, label=distrib_name)
    ax[1].loglog(dimensions, n_total, label=distrib_name)
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Dimensions')
ax[0].set_ylabel('Runtime')
ax[1].set_xlabel('Dimensions')
ax[1].set_ylabel('Total Samples')
fig.suptitle('Comparing Dimensions')
plt.savefig('../outputs/comparison_tests/dimension_plot.png',dpi=200)
