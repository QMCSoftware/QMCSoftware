# %%
from pandas import read_csv
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline

# %%
distrib_names = ['IIDStdUniform','IIDStdGaussian','Lattice','Sobol']

# %% [markdown]
# # Absolute Tolerance Plots

# %%
df_abstols = read_csv('../outputs/comparison_tests/abs_tol.csv')
df_abstols.loc[:10]
# Out:
#     Unnamed: 0  abs_tol  IIDStdUniform_solution  IIDStdGaussian_solution  \
# 0            0   0.0005                     NaN                      NaN
# 1            1   0.0010                     NaN                 2.168435
# 2            2   0.0015                2.168478                 2.168667
# 3            3   0.0020                2.168726                 2.168156
# 4            4   0.0025                2.168246                 2.168391
# 5            5   0.0030                2.167688                 2.168159
# 6            6   0.0035                2.168744                 2.168334
# 7            7   0.0040                2.169340                 2.167062
# 8            8   0.0045                2.169133                 2.167648
# 9            9   0.0050                2.169428                 2.168410
# 10          10   0.0055                2.169046                 2.168017
#
#     Lattice_solution  Sobol_solution  IIDStdUniform_time  IIDStdGaussian_time  \
# 0           2.168330        2.168169                 NaN                  NaN
# 1           2.168415        2.168439                 NaN             3.483122
# 2           2.168270        2.168439            6.231957             1.793089
# 3           2.168270        2.168439            3.515987             1.014234
# 4           2.168270        2.168709            2.298319             0.650542
# 5           2.168270        2.168709            1.575100             0.449320
# 6           2.168270        2.168709            1.164484             0.331741
# 7           2.168165        2.168709            0.893908             0.255740
# 8           2.168165        2.168315            0.712929             0.204592
# 9           2.168165        2.168315            0.574531             0.163952
# 10          2.168165        2.168315            0.469543             0.145488
#
#     Lattice_time  Sobol_time  IIDStdUniform_n  IIDStdGaussian_n  Lattice_n  \
# 0       0.084002    0.177616              NaN               NaN     4096.0
# 1       0.048137    0.140379              NaN        42585463.0     2048.0
# 2       0.021338    0.040676       18218512.0        18927157.0     1024.0
# 3       0.020417    0.036639       10248137.0        10646750.0     1024.0
# 4       0.019818    0.022841        6558992.0         6814105.0     1024.0
# 5       0.019543    0.023149        4555012.0         4732174.0     1024.0
# 6       0.020450    0.023004        3346676.0         3476835.0     1024.0
# 7       0.012224    0.023306        2562419.0         2662072.0      512.0
# 8       0.013655    0.014807        2024735.0         2103473.0      512.0
# 9       0.013021    0.015738        1640132.0         1703911.0      512.0
# 10      0.016606    0.019428        1355570.0         1408279.0      512.0
#
#     Sobol_n
# 0    8192.0
# 1    2048.0
# 2    2048.0
# 3    2048.0
# 4    1024.0
# 5    1024.0
# 6    1024.0
# 7    1024.0
# 8     512.0
# 9     512.0
# 10    512.0

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
abstols = df_abstols['abs_tol'].values
for distrib_name in distrib_names:
    times = df_abstols[distrib_name+'_time'].values
    n_total = df_abstols[distrib_name+'_n'].values
    ax[0].loglog(abstols, times, label=distrib_name)
    ax[1].loglog(abstols, n_total, label=distrib_name)
ax[0].legend(loc='upper left')
ax[0].set_xlim(ax[0].get_xlim()[::-1])
ax[1].set_xlim(ax[1].get_xlim()[::-1])
ax[0].set_xlabel('Absolute Tolerance')
ax[0].set_ylabel('Runtime')
ax[1].set_xlabel('Absolute Tolerance')
ax[1].set_ylabel('Total Samples')
fig.suptitle('Comparing Absolute Tolerances')
plt.savefig('../outputs/comparison_tests/abstols_plot.png',dpi=200)

# %% [markdown]
# # Dimension Plots

# %%
df_dimensions = read_csv('../outputs/comparison_tests/dimension.csv')
df_dimensions
# Out:
#    Unnamed: 0  dimension  IIDStdUniform_solution  IIDStdGaussian_solution  \
# 0           0        1.0                1.420496                 1.415293
# 1           1        2.0                1.812768                 1.796743
# 2           2        3.0                2.175421                 2.183398
# 3           3        4.0                2.176911                 2.172590
# 4           4        5.0                1.206866                 1.147861
# 5           5        6.0               -2.270947                -2.304987
# 6           6        7.0              -11.043120               -11.061916
# 7           7        8.0              -30.631618               -30.610211
#
#    Lattice_solution  Sobol_solution  IIDStdUniform_time  IIDStdGaussian_time  \
# 0          1.372271        1.372271            0.002441             0.001496
# 1          1.795122        1.778721            0.001889             0.001086
# 2          2.137250        2.122099            0.002688             0.001508
# 3          2.128185        2.110778            0.009936             0.002816
# 4          1.219692        1.095942            0.041955             0.007003
# 5         -2.324603       -2.325779            0.120772             0.025142
# 6        -11.055774      -11.056204            0.414308             0.073605
# 7        -30.609742      -30.609051            1.525054             0.239324
#
#    Lattice_time  Sobol_time  IIDStdUniform_n  IIDStdGaussian_n  Lattice_n  \
# 0      0.002209    0.009446            768.0             768.0       16.0
# 1      0.001460    0.006600           1595.0            1545.0       16.0
# 2      0.001332    0.006577           4612.0            4771.0       16.0
# 3      0.001725    0.006473          16644.0           16155.0       16.0
# 4      0.001332    0.007617          56817.0           51823.0       16.0
# 5      0.047293    0.177338         170369.0          179633.0     2048.0
# 6      0.215828    0.822057         542158.0          472699.0     8192.0
# 7      4.028025    0.874088        1684401.0         1385837.0   131072.0
#
#    Sobol_n
# 0     16.0
# 1     16.0
# 2     16.0
# 3     16.0
# 4     16.0
# 5   8192.0
# 6  32768.0
# 7  32768.0

# %%
fig,ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
dimensions = df_dimensions['dimension']
for distrib_name in distrib_names:
    times = df_dimensions[distrib_name+'_time'].values
    n_total = df_dimensions[distrib_name+'_n'].values
    ax[0].plot(dimensions, times, label=distrib_name)
    ax[1].loglog(dimensions, n_total, label=distrib_name)
ax[0].legend(loc='upper right')
ax[0].set_xlabel('Dimensions')
ax[0].set_ylabel('Runtime')
ax[1].set_xlabel('Dimensions')
ax[1].set_ylabel('Total Samples')
fig.suptitle('Comparing Dimensions')
plt.savefig('../outputs/comparison_tests/dimension_plot.png',dpi=200)
